# %% [markdown]
# # Reinforcement learning and deep-learning
#
# ## General outline for this assingment
#
# * Q-learning, openai taxi problem
# * Deep Q-learning, control inverted pendelum
# * Image classification with pytorch for MNIST dataset
#
# This assignment combines the elements of comprehension and implementation. You will be responsible for coding in some sections, while in others, we will provide you with code to study.
#
# ### Q-Learning
#
# In this task, you will employ Q-learning to tackle decision-making in a grid world game. This will provide you with a foundational grasp of Q-learning and the principles of reinforcement learning.
#
# To set up the environment for the first two tasks, you'll need to install the required software. https://pypi.org/project/gymnasium/
#
# pip install gymnasium
#
#
# ### Deep Q-Learning
#
# Deep Q-learning combines neural networks with Q-learning. In this task, you're embarking on a rather ambitious journey. Your goal is to construct a neural network from the ground up and we will show how to apply it to a reinforcement learning problem. This endeavor aims to lay a solid foundation for your comprehension of neural networks and the inherent challenges they pose. This may well be one of the very few opportunities you'll have to create such a network from scratch, granting you insight into what transpires behind the scenes. Following this, you'll likely rely on libraries like PyTorch or TensorFlow, which abstract much of the mathematics.
#
# The core concept behind deep Q-learning involves approximating the Q-table with a neural network. However, as you'll soon discover, this endeavor is far from straightforward.
#
#
# ### CNN + dense with pytorch
#
# To wrap up, you will employ PyTorch to tackle an image classification problem, specifically the classification of handwritten numbers. In this segment, we will demonstrate how PyTorch can be used to construct neural networks. Your objective is to enhance the accuracy of this model to reach a minimum of 98%.
#
# You can easily install pytorch through (it is enough with just cpu support, if you have an nvidia graphics card you can try the cuda installation): https://pytorch.org/

# %% [markdown]
# # Q-Learning
#
# In reinforcement learning, the primary aim is to maximize future rewards. While this may not seem significantly different from supervised learning, the implications are profound. Consider the scenario where you want an AI to navigate a maze: at each time step, the AI can make a move in any valid direction. If you were to approach this as a regression problem, akin to supervised learning, you would need to know the precise solution for every step, which becomes infeasible for complex problems. Reinforcement learning simplifies the human side of the problem by using rewards. For instance, you can reward the AI only when it successfully solves the maze and allow the AI to explore freely. You don't instruct it on how to solve the maze directly but instead provide a reward for completing the task. The AI will then determine the most effective way to maximize the reward over the entire episode.
#
# If you want a robot to learn how to walk, you would provide rewards for moving in the correct direction and penalties if it falls, but you wouldn't explicitly instruct it on how to walk. This is the advantage of reinforcement learning.
#
# Q-learning represents one of the simplest versions of reinforcement learning.
#
# In this task, we will employ Q-learning to tackle the taxi problem, which is further described in https://gymnasium.farama.org/environments/toy_text/taxi/ and visualization is provided a few cells down. Short summary:
#
#
# >There are four designated pick-up and drop-off locations (Red, Green, Yellow and Blue) in the 5x5 grid world. The taxi starts off at a random square and the passenger at one of the designated locations.
# The goal is move the taxi to the passenger’s location, pick up the passenger, move to the passenger’s desired destination, and drop off the passenger. Once the passenger is dropped off, the episode ends.
# The player receives positive rewards for successfully dropping-off the passenger at the correct location. Negative rewards for incorrect attempts to pick-up/drop-off passenger and for each step where another reward is not received.
#
# Let's start by importing the necessary libraries

# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

# %% [markdown]
# The code below visulizes the environment with random actions, the goal will be to create a policy that chooses actions.

# %%
env_render = gym.make("Taxi-v3", render_mode='human') # create environment with rendering 
state, _ = env_render.reset() # initiate the environment
done = False
i = 0
while not done:
    action = env_render.action_space.sample()  # Samples random actions from our environment. 
    new_state, reward, terminated, truncated, _ = env_render.step(action) # takes as step in our environment
    done = terminated or truncated # checks if we have reached our goal or timed out
    state = new_state # updates the current state.
    if i > 20: # End after 20 steps
        done = True
    i+=1
env_render.close()

# %% [markdown]
# ## The Q-learning algorithm
#
# In Q-learning we want to learn a look-up table that for every state and action has the future discounted reward. It is initialized with zeros.
#
# | State  | a1  | a2  | a3  | a4 |
# |---|---|---|---|---|
# | 1  | 0  | 0  | 0 | 0  |
# | 2  | 0  | 0  | 0 | 0  |
# | ...  | ...  | ...  | ... | ... |
# | N  | 0  | 0  | 0 | 0  |
#
# The training then updates this table to the correct values. It might look something like:
#
# | State  | a1  | a2  | a3  | a4 |
# |---|---|---|---|---|
# | 1  | 0.1  | -5  | 1 | 0.4  |
# | 2  | -1  | -2  | 0 | 4  |
# | ...  | ...  | ...  | ... | ... |
# | N  | 1  | 2  | -2 | 1  |
#
# List of some terms in the feild of Q-learning:
# * State - A state in our environment is a representation of all the information available to make a decision. At time step "t," we have the state "s_t." In the case of the taxi problem, there are 500 different states. Each state is an integer within the range of 0 to 500, and it represents:
#     * 25 different taxi locations
#     * 5 passenger locations
#     * 4 possible destinations
# * Markov decision process (MDP) - Q-learning is an algorithm designed to solve problems involving finite discrete Markov decision processes (MDPs) https://en.wikipedia.org/wiki/Markov_decision_process.
# * Action - The actions is how we transition between states, at time step $t$ the action $a_t$ takes us to $s_{t+1}$. In this case we have 6 possible actions:
#     * 0: Move south (down)
#     * 1: Move north (up)
#     * 2: Move east (right)
#     * 3: Move west (left)
#     * 4: Pickup passenger
#     * 5: Drop off passenger
# * Reward - In reinforcement learning, the system provides rewards and penalties to guide the learning process. When the actor successfully completes a task or makes a correct move, a reward $r$ is given. Conversely, penalties can be imposed for suboptimal or incorrect actions. These rewards and penalties serve as the means to influence and shape what the algorithm attempts to learn and optimize. The algorithm aims to maximize the cumulative rewards over time by making decisions that lead to higher overall rewards and fewer penalties.
# * Q-table - The q table contains for every state (s) and action (a) the expected future discounted reward. Often written as Q(s, a), see above.
# * Policy - How do we choose our action, Q(s, a) outputs how good a action is but not directly which action to choose.
# * Greedy policy - For a state choose the action that has the highest expected reward.
# * Epsilon greedy policy - During training allow for exploration by having a probability of choosing a random action instead of greedy. Exploration is necessary for learning, without it the learning can get stuck in the same solution.
# * Episode - One espisode is the agient interacting with the environment from start to finish or termination i.e. a timeseries of states and actions.
#
# The q-table can be initated with zeros. It can be updated as:
#
# $Q(s_t, a_t) = (1- \alpha)Q(s_t, a_t) + \alpha(r_t + \gamma \underbrace{\max}_{a} Q(s_{t+1}, a))$
#
# where $\alpha$ is the learning rate and $\gamma$ is the dicount factor. For training, we want a policy that both explores new paths while at the same time exploits the current best solution. The solution is an epsilon greedy policy. There is more information at https://en.wikipedia.org/wiki/Q-learning. Also notice that we never update the Q values for the goal state, as the episode will terminate upon reaching the goal. The epsilon greedy policy:
#
# $a \begin{cases} random & \textrm{With probability } \epsilon \\
#                 greedy &  \textrm{With probability } 1 - \epsilon \end{cases}$
#
# Where $\epsilon$ is ussually decresing with traning, here is exponential decay.
#
# $ \epsilon = \epsilon_{\textrm{min}} + (\epsilon_{\textrm{max}} -\epsilon_{\textrm{min}}) e^{- \lambda i_e}$
#
# where $\epsilon_{\textrm{min}}$ is the minimum value of $\epsilon$, i.e. we allways want some exploration, otherwise we wont learn anything new. $\epsilon_{\textrm{max}}$ usually set to $1$, how much exploration to start of with. $\lambda$ is the decay rate, how fast should we decreese the amount of exploration. $i_e$ is how many episodes we have trained on.
#
# Next we can check how many state and actions our environment has.

# %%
env = gym.make("Taxi-v3")
num_states = env.observation_space.n
num_actions = env.action_space.n
print('Number of states', num_states, 'and number of actions', num_actions)
# Out:
# Number of states 500 and number of actions 6

# %% [markdown]
# We define our hyper parameters.

# %%
# Hyperparameters
learning_rate = 0.1 # aplha in our q-learning update
discount_factor = 0.99 # gamma
epsilon = 1.0 # epsilon
epsilon_max = 1.0 # epsilon max
epsilon_min = 0.01 # epsilon min
epsilon_lambda = 0.01 # lambda
num_episodes = 5000

# %% [markdown]
# ## Exersice 1.1: Q-learning
#
# Here the task is to implement the Q-learning algorithm.

# %%
# Initiate q-table

q_table = np.zeros((500,6))


# Q-learning algorithm
for episode in range(num_episodes):
    state, info = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        # Calculate action with exploration-exploitation trade-off
        if np.random.rand() < epsilon:
            action = np.random.randint(0, 6)  # Assuming 6 possible actions
        else:
            action = np.argmax(q_table[state, :])
        
        
        # step 
        new_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Q-value update
        best_future_q = np.max(q_table[new_state, :])
        q_table[state, action] = q_table[state, action] + learning_rate * (reward + discount_factor * best_future_q - q_table[state, action])
        
        
        total_reward += reward
        state = new_state
    
    # Decay exploration probability (epsilon)
    epsilon = epsilon_min + (epsilon_max - epsilon_min)*np.exp(-epsilon_lambda*episode)
    print(f"Episode: {episode+1}, Total Reward: {total_reward}")
# Out:
# Episode: 1, Total Reward: -713
# Episode: 2, Total Reward: -668
# Episode: 3, Total Reward: -866
# Episode: 4, Total Reward: -695
# Episode: 5, Total Reward: -767
# Episode: 6, Total Reward: -758
# Episode: 7, Total Reward: -974
# Episode: 8, Total Reward: -758
# Episode: 9, Total Reward: -785
# Episode: 10, Total Reward: -875
# Episode: 11, Total Reward: -524
# Episode: 12, Total Reward: -364
# Episode: 13, Total Reward: -704
# Episode: 14, Total Reward: -704
# Episode: 15, Total Reward: -731
# Episode: 16, Total Reward: -776
# Episode: 17, Total Reward: -677
# Episode: 18, Total Reward: -839
# Episode: 19, Total Reward: -623
# Episode: 20, Total Reward: -632
# Episode: 21, Total Reward: -767
# Episode: 22, Total Reward: -253
# Episode: 23, Total Reward: -731
# Episode: 24, Total Reward: -695
# Episode: 25, Total Reward: -677
# Episode: 26, Total Reward: -749
# Episode: 27, Total Reward: -695
# Episode: 28, Total Reward: -695
# Episode: 29, Total Reward: -632
# Episode: 30, Total Reward: -785
# Episode: 31, Total Reward: -632
# Episode: 32, Total Reward: -758
# Episode: 33, Total Reward: -243
# Episode: 34, Total Reward: -668
# Episode: 35, Total Reward: -650
# Episode: 36, Total Reward: -641
# Episode: 37, Total Reward: -506
# Episode: 38, Total Reward: -686
# Episode: 39, Total Reward: -362
# Episode: 40, Total Reward: -650
# Episode: 41, Total Reward: -614
# Episode: 42, Total Reward: -650
# Episode: 43, Total Reward: -659
# Episode: 44, Total Reward: -623
# Episode: 45, Total Reward: -605
# Episode: 46, Total Reward: -560
# Episode: 47, Total Reward: -614
# Episode: 48, Total Reward: -551
# Episode: 49, Total Reward: -157
# Episode: 50, Total Reward: -551
# Episode: 51, Total Reward: -533
# Episode: 52, Total Reward: -578
# Episode: 53, Total Reward: -623
# Episode: 54, Total Reward: -204
# Episode: 55, Total Reward: -551
# Episode: 56, Total Reward: -623
# Episode: 57, Total Reward: -569
# Episode: 58, Total Reward: -623
# Episode: 59, Total Reward: -542
# Episode: 60, Total Reward: -470
# Episode: 61, Total Reward: -632
# Episode: 62, Total Reward: -515
# Episode: 63, Total Reward: -551
# Episode: 64, Total Reward: -112
# Episode: 65, Total Reward: -524
# Episode: 66, Total Reward: -533
# Episode: 67, Total Reward: -506
# Episode: 68, Total Reward: -524
# Episode: 69, Total Reward: -623
# Episode: 70, Total Reward: -479
# Episode: 71, Total Reward: -461
# Episode: 72, Total Reward: -488
# Episode: 73, Total Reward: -340
# Episode: 74, Total Reward: -578
# Episode: 75, Total Reward: -328
# Episode: 76, Total Reward: -382
# Episode: 77, Total Reward: -479
# Episode: 78, Total Reward: -452
# Episode: 79, Total Reward: -452
# Episode: 80, Total Reward: -479
# Episode: 81, Total Reward: -389
# Episode: 82, Total Reward: -470
# Episode: 83, Total Reward: -497
# Episode: 84, Total Reward: -452
# Episode: 85, Total Reward: -470
# Episode: 86, Total Reward: -506
# Episode: 87, Total Reward: -356
# Episode: 88, Total Reward: -461
# Episode: 89, Total Reward: -398
# Episode: 90, Total Reward: -135
# Episode: 91, Total Reward: -470
# Episode: 92, Total Reward: -452
# Episode: 93, Total Reward: -425
# Episode: 94, Total Reward: -416
# Episode: 95, Total Reward: -319
# Episode: 96, Total Reward: -117
# Episode: 97, Total Reward: -497
# Episode: 98, Total Reward: -497
# Episode: 99, Total Reward: -380
# Episode: 100, Total Reward: -452
# Episode: 101, Total Reward: -407
# Episode: 102, Total Reward: -289
# Episode: 103, Total Reward: -461
# Episode: 104, Total Reward: -452
# Episode: 105, Total Reward: -335
# Episode: 106, Total Reward: -425
# Episode: 107, Total Reward: -479
# Episode: 108, Total Reward: -85
# Episode: 109, Total Reward: -37
# Episode: 110, Total Reward: -380
# Episode: 111, Total Reward: -334
# Episode: 112, Total Reward: -130
# Episode: 113, Total Reward: -434
# Episode: 114, Total Reward: -407
# Episode: 115, Total Reward: -380
# Episode: 116, Total Reward: -434
# Episode: 117, Total Reward: -236
# Episode: 118, Total Reward: -416
# Episode: 119, Total Reward: -368
# Episode: 120, Total Reward: -173
# Episode: 121, Total Reward: -416
# Episode: 122, Total Reward: -371
# Episode: 123, Total Reward: -17
# Episode: 124, Total Reward: -398
# Episode: 125, Total Reward: -380
# Episode: 126, Total Reward: -398
# Episode: 127, Total Reward: -371
# Episode: 128, Total Reward: -255
# Episode: 129, Total Reward: -389
# Episode: 130, Total Reward: -98
# Episode: 131, Total Reward: -371
# Episode: 132, Total Reward: -202
# Episode: 133, Total Reward: -371
# Episode: 134, Total Reward: -443
# Episode: 135, Total Reward: -398
# Episode: 136, Total Reward: -326
# Episode: 137, Total Reward: -104
# Episode: 138, Total Reward: -109
# Episode: 139, Total Reward: -407
# Episode: 140, Total Reward: -190
# Episode: 141, Total Reward: -398
# Episode: 142, Total Reward: -101
# Episode: 143, Total Reward: -362
# Episode: 144, Total Reward: -297
# Episode: 145, Total Reward: -190
# Episode: 146, Total Reward: -308
# Episode: 147, Total Reward: -335
# Episode: 148, Total Reward: -353
# Episode: 149, Total Reward: -216
# Episode: 150, Total Reward: -380
# Episode: 151, Total Reward: -272
# Episode: 152, Total Reward: -281
# Episode: 153, Total Reward: -362
# Episode: 154, Total Reward: -317
# Episode: 155, Total Reward: -371
# Episode: 156, Total Reward: -326
# Episode: 157, Total Reward: -326
# Episode: 158, Total Reward: -362
# Episode: 159, Total Reward: -261
# Episode: 160, Total Reward: -118
# Episode: 161, Total Reward: -107
# Episode: 162, Total Reward: -150
# Episode: 163, Total Reward: -216
# Episode: 164, Total Reward: -317
# Episode: 165, Total Reward: -308
# Episode: 166, Total Reward: -126
# Episode: 167, Total Reward: -73
# Episode: 168, Total Reward: -269
# Episode: 169, Total Reward: -308
# Episode: 170, Total Reward: -371
# Episode: 171, Total Reward: -86
# Episode: 172, Total Reward: -264
# Episode: 173, Total Reward: -44
# Episode: 174, Total Reward: -101
# Episode: 175, Total Reward: -308
# Episode: 176, Total Reward: -149
# Episode: 177, Total Reward: -317
# Episode: 178, Total Reward: -308
# Episode: 179, Total Reward: -299
# Episode: 180, Total Reward: -290
# Episode: 181, Total Reward: -26
# Episode: 182, Total Reward: -290
# Episode: 183, Total Reward: -344
# Episode: 184, Total Reward: -240
# Episode: 185, Total Reward: -281
# Episode: 186, Total Reward: -281
# Episode: 187, Total Reward: -299
# Episode: 188, Total Reward: -146
# Episode: 189, Total Reward: -174
# Episode: 190, Total Reward: -117
# Episode: 191, Total Reward: -290
# Episode: 192, Total Reward: -98
# Episode: 193, Total Reward: -209
# Episode: 194, Total Reward: -197
# Episode: 195, Total Reward: -308
# Episode: 196, Total Reward: -15
# Episode: 197, Total Reward: -308
# Episode: 198, Total Reward: -317
# Episode: 199, Total Reward: -3
# Episode: 200, Total Reward: -299
# Episode: 201, Total Reward: -9
# Episode: 202, Total Reward: -192
# Episode: 203, Total Reward: -272
# Episode: 204, Total Reward: -317
# Episode: 205, Total Reward: -182
# Episode: 206, Total Reward: -237
# Episode: 207, Total Reward: -299
# Episode: 208, Total Reward: -3
# Episode: 209, Total Reward: -171
# Episode: 210, Total Reward: -258
# Episode: 211, Total Reward: -141
# Episode: 212, Total Reward: -185
# Episode: 213, Total Reward: -264
# Episode: 214, Total Reward: -218
# Episode: 215, Total Reward: -344
# Episode: 216, Total Reward: -299
# Episode: 217, Total Reward: -299
# Episode: 218, Total Reward: 11
# Episode: 219, Total Reward: -173
# Episode: 220, Total Reward: -185
# Episode: 221, Total Reward: -276
# Episode: 222, Total Reward: -263
# Episode: 223, Total Reward: -1
# Episode: 224, Total Reward: 8
# Episode: 225, Total Reward: 11
# Episode: 226, Total Reward: -90
# Episode: 227, Total Reward: -67
# Episode: 228, Total Reward: -160
# Episode: 229, Total Reward: -299
# Episode: 230, Total Reward: -227
# Episode: 231, Total Reward: -159
# Episode: 232, Total Reward: -263
# Episode: 233, Total Reward: -14
# Episode: 234, Total Reward: -290
# Episode: 235, Total Reward: -51
# Episode: 236, Total Reward: -114
# Episode: 237, Total Reward: 4
# Episode: 238, Total Reward: -281
# Episode: 239, Total Reward: -23
# Episode: 240, Total Reward: -184
# Episode: 241, Total Reward: -172
# Episode: 242, Total Reward: -299
# Episode: 243, Total Reward: -209
# Episode: 244, Total Reward: -19
# Episode: 245, Total Reward: -33
# Episode: 246, Total Reward: -140
# Episode: 247, Total Reward: -13
# Episode: 248, Total Reward: -173
# Episode: 249, Total Reward: -263
# Episode: 250, Total Reward: -53
# Episode: 251, Total Reward: -263
# Episode: 252, Total Reward: -160
# Episode: 253, Total Reward: -236
# Episode: 254, Total Reward: -245
# Episode: 255, Total Reward: -141
# Episode: 256, Total Reward: -80
# Episode: 257, Total Reward: -263
# Episode: 258, Total Reward: -138
# Episode: 259, Total Reward: -16
# Episode: 260, Total Reward: -27
# Episode: 261, Total Reward: -105
# Episode: 262, Total Reward: -189
# Episode: 263, Total Reward: -169
# Episode: 264, Total Reward: -218
# Episode: 265, Total Reward: -111
# Episode: 266, Total Reward: -272
# Episode: 267, Total Reward: -254
# Episode: 268, Total Reward: -67
# Episode: 269, Total Reward: -272
# Episode: 270, Total Reward: -70
# Episode: 271, Total Reward: -227
# Episode: 272, Total Reward: -12
# Episode: 273, Total Reward: -66
# Episode: 274, Total Reward: -95
# Episode: 275, Total Reward: -49
# Episode: 276, Total Reward: -82
# Episode: 277, Total Reward: 8
# Episode: 278, Total Reward: -167
# Episode: 279, Total Reward: -141
# Episode: 280, Total Reward: -227
# Episode: 281, Total Reward: -54
# Episode: 282, Total Reward: -257
# Episode: 283, Total Reward: -27
# Episode: 284, Total Reward: -225
# Episode: 285, Total Reward: -263
# Episode: 286, Total Reward: 3
# Episode: 287, Total Reward: -186
# Episode: 288, Total Reward: -66
# Episode: 289, Total Reward: -94
# Episode: 290, Total Reward: -178
# Episode: 291, Total Reward: -153
# Episode: 292, Total Reward: -141
# Episode: 293, Total Reward: -236
# Episode: 294, Total Reward: -188
# Episode: 295, Total Reward: -102
# Episode: 296, Total Reward: -98
# Episode: 297, Total Reward: -84
# Episode: 298, Total Reward: -23
# Episode: 299, Total Reward: -142
# Episode: 300, Total Reward: -99
# Episode: 301, Total Reward: -135
# Episode: 302, Total Reward: -91
# Episode: 303, Total Reward: -150
# Episode: 304, Total Reward: -111
# Episode: 305, Total Reward: -263
# Episode: 306, Total Reward: -223
# Episode: 307, Total Reward: -143
# Episode: 308, Total Reward: -210
# Episode: 309, Total Reward: -3
# Episode: 310, Total Reward: -143
# Episode: 311, Total Reward: -59
# Episode: 312, Total Reward: -53
# Episode: 313, Total Reward: -151
# Episode: 314, Total Reward: -227
# Episode: 315, Total Reward: -165
# Episode: 316, Total Reward: -114
# Episode: 317, Total Reward: -146
# Episode: 318, Total Reward: -179
# Episode: 319, Total Reward: -133
# Episode: 320, Total Reward: -122
# Episode: 321, Total Reward: -91
# Episode: 322, Total Reward: -117
# Episode: 323, Total Reward: -141
# Episode: 324, Total Reward: -196
# Episode: 325, Total Reward: -107
# Episode: 326, Total Reward: -6
# Episode: 327, Total Reward: -24
# Episode: 328, Total Reward: -123
# Episode: 329, Total Reward: -197
# Episode: 330, Total Reward: -59
# Episode: 331, Total Reward: -7
# Episode: 332, Total Reward: 14
# Episode: 333, Total Reward: -48
# Episode: 334, Total Reward: -129
# Episode: 335, Total Reward: -245
# Episode: 336, Total Reward: 14
# Episode: 337, Total Reward: -82
# Episode: 338, Total Reward: -227
# Episode: 339, Total Reward: -63
# Episode: 340, Total Reward: 12
# Episode: 341, Total Reward: -254
# Episode: 342, Total Reward: -80
# Episode: 343, Total Reward: -45
# Episode: 344, Total Reward: -254
# Episode: 345, Total Reward: 5
# Episode: 346, Total Reward: -54
# Episode: 347, Total Reward: -236
# Episode: 348, Total Reward: 13
# Episode: 349, Total Reward: -12
# Episode: 350, Total Reward: -58
# Episode: 351, Total Reward: -108
# Episode: 352, Total Reward: -96
# Episode: 353, Total Reward: -100
# Episode: 354, Total Reward: -45
# Episode: 355, Total Reward: -158
# Episode: 356, Total Reward: -35
# Episode: 357, Total Reward: -74
# Episode: 358, Total Reward: -47
# Episode: 359, Total Reward: -83
# Episode: 360, Total Reward: -29
# Episode: 361, Total Reward: -175
# Episode: 362, Total Reward: 9
# Episode: 363, Total Reward: -118
# Episode: 364, Total Reward: -103
# Episode: 365, Total Reward: -23
# Episode: 366, Total Reward: -51
# Episode: 367, Total Reward: -27
# Episode: 368, Total Reward: -132
# Episode: 369, Total Reward: -19
# Episode: 370, Total Reward: -227
# Episode: 371, Total Reward: -34
# Episode: 372, Total Reward: 6
# Episode: 373, Total Reward: -140
# Episode: 374, Total Reward: -110
# Episode: 375, Total Reward: -70
# Episode: 376, Total Reward: -126
# Episode: 377, Total Reward: -3
# Episode: 378, Total Reward: -132
# Episode: 379, Total Reward: -13
# Episode: 380, Total Reward: -171
# Episode: 381, Total Reward: -114
# Episode: 382, Total Reward: -167
# Episode: 383, Total Reward: -263
# Episode: 384, Total Reward: -25
# Episode: 385, Total Reward: 1
# Episode: 386, Total Reward: -152
# Episode: 387, Total Reward: -14
# Episode: 388, Total Reward: -67
# Episode: 389, Total Reward: -227
# Episode: 390, Total Reward: -91
# Episode: 391, Total Reward: 4
# Episode: 392, Total Reward: 7
# Episode: 393, Total Reward: -43
# Episode: 394, Total Reward: -91
# Episode: 395, Total Reward: -47
# Episode: 396, Total Reward: -204
# Episode: 397, Total Reward: -84
# Episode: 398, Total Reward: -78
# Episode: 399, Total Reward: -86
# Episode: 400, Total Reward: -91
# Episode: 401, Total Reward: -39
# Episode: 402, Total Reward: -111
# Episode: 403, Total Reward: -18
# Episode: 404, Total Reward: -132
# Episode: 405, Total Reward: -109
# Episode: 406, Total Reward: -126
# Episode: 407, Total Reward: -137
# Episode: 408, Total Reward: -61
# Episode: 409, Total Reward: -218
# Episode: 410, Total Reward: -1
# Episode: 411, Total Reward: -97
# Episode: 412, Total Reward: -6
# Episode: 413, Total Reward: -95
# Episode: 414, Total Reward: -95
# Episode: 415, Total Reward: -2
# Episode: 416, Total Reward: -67
# Episode: 417, Total Reward: 15
# Episode: 418, Total Reward: 3
# Episode: 419, Total Reward: -218
# Episode: 420, Total Reward: -81
# Episode: 421, Total Reward: -11
# Episode: 422, Total Reward: -97
# Episode: 423, Total Reward: -45
# Episode: 424, Total Reward: -179
# Episode: 425, Total Reward: -50
# Episode: 426, Total Reward: -78
# Episode: 427, Total Reward: -54
# Episode: 428, Total Reward: -95
# Episode: 429, Total Reward: 11
# Episode: 430, Total Reward: -108
# Episode: 431, Total Reward: -1
# Episode: 432, Total Reward: -209
# Episode: 433, Total Reward: -144
# Episode: 434, Total Reward: -93
# Episode: 435, Total Reward: -7
# Episode: 436, Total Reward: -88
# Episode: 437, Total Reward: -30
# Episode: 438, Total Reward: -101
# Episode: 439, Total Reward: -129
# Episode: 440, Total Reward: -80
# Episode: 441, Total Reward: -57
# Episode: 442, Total Reward: -34
# Episode: 443, Total Reward: -32
# Episode: 444, Total Reward: -141
# Episode: 445, Total Reward: -32
# Episode: 446, Total Reward: -82
# Episode: 447, Total Reward: -4
# Episode: 448, Total Reward: -131
# Episode: 449, Total Reward: -89
# Episode: 450, Total Reward: -8
# Episode: 451, Total Reward: -176
# Episode: 452, Total Reward: -126
# Episode: 453, Total Reward: -82
# Episode: 454, Total Reward: -92
# Episode: 455, Total Reward: -84
# Episode: 456, Total Reward: -111
# Episode: 457, Total Reward: -61
# Episode: 458, Total Reward: -19
# Episode: 459, Total Reward: -124
# Episode: 460, Total Reward: -59
# Episode: 461, Total Reward: -7
# Episode: 462, Total Reward: -30
# Episode: 463, Total Reward: -8
# Episode: 464, Total Reward: -157
# Episode: 465, Total Reward: -209
# Episode: 466, Total Reward: -58
# Episode: 467, Total Reward: -144
# Episode: 468, Total Reward: -50
# Episode: 469, Total Reward: -9
# Episode: 470, Total Reward: -111
# Episode: 471, Total Reward: -4
# Episode: 472, Total Reward: -21
# Episode: 473, Total Reward: 1
# Episode: 474, Total Reward: -97
# Episode: 475, Total Reward: 11
# Episode: 476, Total Reward: -40
# Episode: 477, Total Reward: -125
# Episode: 478, Total Reward: -10
# Episode: 479, Total Reward: -21
# Episode: 480, Total Reward: -4
# Episode: 481, Total Reward: -142
# Episode: 482, Total Reward: -24
# Episode: 483, Total Reward: -98
# Episode: 484, Total Reward: -112
# Episode: 485, Total Reward: -99
# Episode: 486, Total Reward: -113
# Episode: 487, Total Reward: -71
# Episode: 488, Total Reward: -18
# Episode: 489, Total Reward: 8
# Episode: 490, Total Reward: -148
# Episode: 491, Total Reward: -10
# Episode: 492, Total Reward: 9
# Episode: 493, Total Reward: -86
# Episode: 494, Total Reward: 12
# Episode: 495, Total Reward: -91
# Episode: 496, Total Reward: -8
# Episode: 497, Total Reward: -41
# Episode: 498, Total Reward: -84
# Episode: 499, Total Reward: -55
# Episode: 500, Total Reward: -99
# Episode: 501, Total Reward: 4
# Episode: 502, Total Reward: -142
# Episode: 503, Total Reward: 12
# Episode: 504, Total Reward: -87
# Episode: 505, Total Reward: -48
# Episode: 506, Total Reward: -100
# Episode: 507, Total Reward: -98
# Episode: 508, Total Reward: 1
# Episode: 509, Total Reward: -16
# Episode: 510, Total Reward: 11
# Episode: 511, Total Reward: -7
# Episode: 512, Total Reward: -143
# Episode: 513, Total Reward: -12
# Episode: 514, Total Reward: -62
# Episode: 515, Total Reward: 1
# Episode: 516, Total Reward: 6
# Episode: 517, Total Reward: -106
# Episode: 518, Total Reward: 13
# Episode: 519, Total Reward: -157
# Episode: 520, Total Reward: 11
# Episode: 521, Total Reward: -50
# Episode: 522, Total Reward: -48
# Episode: 523, Total Reward: -119
# Episode: 524, Total Reward: -141
# Episode: 525, Total Reward: -13
# Episode: 526, Total Reward: -1
# Episode: 527, Total Reward: -116
# Episode: 528, Total Reward: -98
# Episode: 529, Total Reward: -16
# Episode: 530, Total Reward: -65
# Episode: 531, Total Reward: -95
# Episode: 532, Total Reward: -62
# Episode: 533, Total Reward: -7
# Episode: 534, Total Reward: -99
# Episode: 535, Total Reward: 3
# Episode: 536, Total Reward: -22
# Episode: 537, Total Reward: 7
# Episode: 538, Total Reward: 4
# Episode: 539, Total Reward: -72
# Episode: 540, Total Reward: -48
# Episode: 541, Total Reward: -91
# Episode: 542, Total Reward: -15
# Episode: 543, Total Reward: -95
# Episode: 544, Total Reward: -38
# Episode: 545, Total Reward: -146
# Episode: 546, Total Reward: -146
# Episode: 547, Total Reward: -130
# Episode: 548, Total Reward: 11
# Episode: 549, Total Reward: -2
# Episode: 550, Total Reward: -85
# Episode: 551, Total Reward: -105
# Episode: 552, Total Reward: -87
# Episode: 553, Total Reward: -8
# Episode: 554, Total Reward: -96
# Episode: 555, Total Reward: -31
# Episode: 556, Total Reward: -52
# Episode: 557, Total Reward: -55
# Episode: 558, Total Reward: -41
# Episode: 559, Total Reward: -49
# Episode: 560, Total Reward: -69
# Episode: 561, Total Reward: 13
# Episode: 562, Total Reward: 6
# Episode: 563, Total Reward: -23
# Episode: 564, Total Reward: -24
# Episode: 565, Total Reward: -81
# Episode: 566, Total Reward: -15
# Episode: 567, Total Reward: 9
# Episode: 568, Total Reward: -42
# Episode: 569, Total Reward: -3
# Episode: 570, Total Reward: 10
# Episode: 571, Total Reward: -61
# Episode: 572, Total Reward: -27
# Episode: 573, Total Reward: -12
# Episode: 574, Total Reward: 4
# Episode: 575, Total Reward: 3
# Episode: 576, Total Reward: -61
# Episode: 577, Total Reward: -99
# Episode: 578, Total Reward: 8
# Episode: 579, Total Reward: -60
# Episode: 580, Total Reward: 9
# Episode: 581, Total Reward: 14
# Episode: 582, Total Reward: -33
# Episode: 583, Total Reward: -15
# Episode: 584, Total Reward: -9
# Episode: 585, Total Reward: -84
# Episode: 586, Total Reward: -6
# Episode: 587, Total Reward: -115
# Episode: 588, Total Reward: 3
# Episode: 589, Total Reward: -86
# Episode: 590, Total Reward: 10
# Episode: 591, Total Reward: -22
# Episode: 592, Total Reward: -38
# Episode: 593, Total Reward: 7
# Episode: 594, Total Reward: -18
# Episode: 595, Total Reward: -80
# Episode: 596, Total Reward: -80
# Episode: 597, Total Reward: -77
# Episode: 598, Total Reward: -67
# Episode: 599, Total Reward: -37
# Episode: 600, Total Reward: 3
# Episode: 601, Total Reward: 13
# Episode: 602, Total Reward: -102
# Episode: 603, Total Reward: -35
# Episode: 604, Total Reward: -16
# Episode: 605, Total Reward: 6
# Episode: 606, Total Reward: -12
# Episode: 607, Total Reward: 14
# Episode: 608, Total Reward: -126
# Episode: 609, Total Reward: -93
# Episode: 610, Total Reward: -101
# Episode: 611, Total Reward: -41
# Episode: 612, Total Reward: -28
# Episode: 613, Total Reward: 13
# Episode: 614, Total Reward: -38
# Episode: 615, Total Reward: -37
# Episode: 616, Total Reward: 13
# Episode: 617, Total Reward: 10
# Episode: 618, Total Reward: -41
# Episode: 619, Total Reward: 10
# Episode: 620, Total Reward: 4
# Episode: 621, Total Reward: 0
# Episode: 622, Total Reward: -35
# Episode: 623, Total Reward: 13
# Episode: 624, Total Reward: -11
# Episode: 625, Total Reward: 12
# Episode: 626, Total Reward: -25
# Episode: 627, Total Reward: -42
# Episode: 628, Total Reward: -34
# Episode: 629, Total Reward: -153
# Episode: 630, Total Reward: -116
# Episode: 631, Total Reward: -127
# Episode: 632, Total Reward: 1
# Episode: 633, Total Reward: 10
# Episode: 634, Total Reward: -108
# Episode: 635, Total Reward: 4
# Episode: 636, Total Reward: 2
# Episode: 637, Total Reward: 11
# Episode: 638, Total Reward: -29
# Episode: 639, Total Reward: -41
# Episode: 640, Total Reward: -113
# Episode: 641, Total Reward: -67
# Episode: 642, Total Reward: -95
# Episode: 643, Total Reward: -46
# Episode: 644, Total Reward: -29
# Episode: 645, Total Reward: 9
# Episode: 646, Total Reward: -52
# Episode: 647, Total Reward: -28
# Episode: 648, Total Reward: -1
# Episode: 649, Total Reward: -55
# Episode: 650, Total Reward: 11
# Episode: 651, Total Reward: -32
# Episode: 652, Total Reward: -77
# Episode: 653, Total Reward: -46
# Episode: 654, Total Reward: -86
# Episode: 655, Total Reward: -5
# Episode: 656, Total Reward: -26
# Episode: 657, Total Reward: -103
# Episode: 658, Total Reward: 14
# Episode: 659, Total Reward: -67
# Episode: 660, Total Reward: -3
# Episode: 661, Total Reward: -55
# Episode: 662, Total Reward: 0
# Episode: 663, Total Reward: -23
# Episode: 664, Total Reward: -34
# Episode: 665, Total Reward: 5
# Episode: 666, Total Reward: -5
# Episode: 667, Total Reward: -5
# Episode: 668, Total Reward: -48
# Episode: 669, Total Reward: 9
# Episode: 670, Total Reward: -10
# Episode: 671, Total Reward: -44
# Episode: 672, Total Reward: -42
# Episode: 673, Total Reward: -80
# Episode: 674, Total Reward: -49
# Episode: 675, Total Reward: -57
# Episode: 676, Total Reward: -11
# Episode: 677, Total Reward: -93
# Episode: 678, Total Reward: -66
# Episode: 679, Total Reward: -18
# Episode: 680, Total Reward: 3
# Episode: 681, Total Reward: 7
# Episode: 682, Total Reward: -55
# Episode: 683, Total Reward: 6
# Episode: 684, Total Reward: 6
# Episode: 685, Total Reward: -47
# Episode: 686, Total Reward: 15
# Episode: 687, Total Reward: 11
# Episode: 688, Total Reward: 6
# Episode: 689, Total Reward: 11
# Episode: 690, Total Reward: -19
# Episode: 691, Total Reward: -40
# Episode: 692, Total Reward: 6
# Episode: 693, Total Reward: -29
# Episode: 694, Total Reward: 4
# Episode: 695, Total Reward: 5
# Episode: 696, Total Reward: 10
# Episode: 697, Total Reward: 7
# Episode: 698, Total Reward: 6
# Episode: 699, Total Reward: -11
# Episode: 700, Total Reward: -72
# Episode: 701, Total Reward: -42
# Episode: 702, Total Reward: -13
# Episode: 703, Total Reward: 5
# Episode: 704, Total Reward: -34
# Episode: 705, Total Reward: -44
# Episode: 706, Total Reward: 11
# Episode: 707, Total Reward: 15
# Episode: 708, Total Reward: 7
# Episode: 709, Total Reward: -34
# Episode: 710, Total Reward: -71
# Episode: 711, Total Reward: -3
# Episode: 712, Total Reward: 5
# Episode: 713, Total Reward: 9
# Episode: 714, Total Reward: -40
# Episode: 715, Total Reward: -33
# Episode: 716, Total Reward: -12
# Episode: 717, Total Reward: 11
# Episode: 718, Total Reward: -61
# Episode: 719, Total Reward: 5
# Episode: 720, Total Reward: -1
# Episode: 721, Total Reward: 13
# Episode: 722, Total Reward: -126
# Episode: 723, Total Reward: -49
# Episode: 724, Total Reward: 12
# Episode: 725, Total Reward: 1
# Episode: 726, Total Reward: -4
# Episode: 727, Total Reward: 8
# Episode: 728, Total Reward: -44
# Episode: 729, Total Reward: 11
# Episode: 730, Total Reward: -46
# Episode: 731, Total Reward: -54
# Episode: 732, Total Reward: -6
# Episode: 733, Total Reward: 13
# Episode: 734, Total Reward: 1
# Episode: 735, Total Reward: 6
# Episode: 736, Total Reward: 11
# Episode: 737, Total Reward: -1
# Episode: 738, Total Reward: 9
# Episode: 739, Total Reward: 10
# Episode: 740, Total Reward: -2
# Episode: 741, Total Reward: -5
# Episode: 742, Total Reward: -80
# Episode: 743, Total Reward: 9
# Episode: 744, Total Reward: -37
# Episode: 745, Total Reward: 0
# Episode: 746, Total Reward: -54
# Episode: 747, Total Reward: -52
# Episode: 748, Total Reward: 7
# Episode: 749, Total Reward: 12
# Episode: 750, Total Reward: -34
# Episode: 751, Total Reward: 11
# Episode: 752, Total Reward: -35
# Episode: 753, Total Reward: -21
# Episode: 754, Total Reward: -25
# Episode: 755, Total Reward: 1
# Episode: 756, Total Reward: -12
# Episode: 757, Total Reward: -30
# Episode: 758, Total Reward: -36
# Episode: 759, Total Reward: 12
# Episode: 760, Total Reward: 12
# Episode: 761, Total Reward: -23
# Episode: 762, Total Reward: -15
# Episode: 763, Total Reward: -124
# Episode: 764, Total Reward: -58
# Episode: 765, Total Reward: 11
# Episode: 766, Total Reward: -12
# Episode: 767, Total Reward: 6
# Episode: 768, Total Reward: -39
# Episode: 769, Total Reward: 10
# Episode: 770, Total Reward: 8
# Episode: 771, Total Reward: -26
# Episode: 772, Total Reward: 3
# Episode: 773, Total Reward: 12
# Episode: 774, Total Reward: 11
# Episode: 775, Total Reward: -52
# Episode: 776, Total Reward: -37
# Episode: 777, Total Reward: -6
# Episode: 778, Total Reward: 6
# Episode: 779, Total Reward: 6
# Episode: 780, Total Reward: 5
# Episode: 781, Total Reward: 12
# Episode: 782, Total Reward: -55
# Episode: 783, Total Reward: -65
# Episode: 784, Total Reward: -109
# Episode: 785, Total Reward: -30
# Episode: 786, Total Reward: -42
# Episode: 787, Total Reward: -20
# Episode: 788, Total Reward: -6
# Episode: 789, Total Reward: -9
# Episode: 790, Total Reward: -19
# Episode: 791, Total Reward: -52
# Episode: 792, Total Reward: 10
# Episode: 793, Total Reward: 4
# Episode: 794, Total Reward: 12
# Episode: 795, Total Reward: 10
# Episode: 796, Total Reward: 10
# Episode: 797, Total Reward: 12
# Episode: 798, Total Reward: -101
# Episode: 799, Total Reward: 7
# Episode: 800, Total Reward: 10
# Episode: 801, Total Reward: 9
# Episode: 802, Total Reward: 1
# Episode: 803, Total Reward: -44
# Episode: 804, Total Reward: 10
# Episode: 805, Total Reward: 0
# Episode: 806, Total Reward: 11
# Episode: 807, Total Reward: 4
# Episode: 808, Total Reward: 9
# Episode: 809, Total Reward: 10
# Episode: 810, Total Reward: 10
# Episode: 811, Total Reward: -104
# Episode: 812, Total Reward: -103
# Episode: 813, Total Reward: 9
# Episode: 814, Total Reward: 7
# Episode: 815, Total Reward: -6
# Episode: 816, Total Reward: -21
# Episode: 817, Total Reward: -30
# Episode: 818, Total Reward: -3
# Episode: 819, Total Reward: 13
# Episode: 820, Total Reward: -10
# Episode: 821, Total Reward: -12
# Episode: 822, Total Reward: 13
# Episode: 823, Total Reward: -2
# Episode: 824, Total Reward: 12
# Episode: 825, Total Reward: -1
# Episode: 826, Total Reward: -22
# Episode: 827, Total Reward: -6
# Episode: 828, Total Reward: 6
# Episode: 829, Total Reward: -17
# Episode: 830, Total Reward: 10
# Episode: 831, Total Reward: -8
# Episode: 832, Total Reward: 5
# Episode: 833, Total Reward: -2
# Episode: 834, Total Reward: 11
# Episode: 835, Total Reward: 8
# Episode: 836, Total Reward: -15
# Episode: 837, Total Reward: 10
# Episode: 838, Total Reward: -88
# Episode: 839, Total Reward: -32
# Episode: 840, Total Reward: 2
# Episode: 841, Total Reward: 0
# Episode: 842, Total Reward: 13
# Episode: 843, Total Reward: 3
# Episode: 844, Total Reward: 11
# Episode: 845, Total Reward: -2
# Episode: 846, Total Reward: 11
# Episode: 847, Total Reward: 3
# Episode: 848, Total Reward: 5
# Episode: 849, Total Reward: -45
# Episode: 850, Total Reward: -15
# Episode: 851, Total Reward: -56
# Episode: 852, Total Reward: -1
# Episode: 853, Total Reward: -6
# Episode: 854, Total Reward: -56
# Episode: 855, Total Reward: -44
# Episode: 856, Total Reward: -10
# Episode: 857, Total Reward: -33
# Episode: 858, Total Reward: -48
# Episode: 859, Total Reward: -29
# Episode: 860, Total Reward: -1
# Episode: 861, Total Reward: 9
# Episode: 862, Total Reward: 9
# Episode: 863, Total Reward: 13
# Episode: 864, Total Reward: -6
# Episode: 865, Total Reward: 10
# Episode: 866, Total Reward: -22
# Episode: 867, Total Reward: 2
# Episode: 868, Total Reward: 3
# Episode: 869, Total Reward: -5
# Episode: 870, Total Reward: -90
# Episode: 871, Total Reward: 9
# Episode: 872, Total Reward: -6
# Episode: 873, Total Reward: -67
# Episode: 874, Total Reward: 12
# Episode: 875, Total Reward: 14
# Episode: 876, Total Reward: 3
# Episode: 877, Total Reward: 10
# Episode: 878, Total Reward: 10
# Episode: 879, Total Reward: 8
# Episode: 880, Total Reward: -19
# Episode: 881, Total Reward: 10
# Episode: 882, Total Reward: -6
# Episode: 883, Total Reward: 5
# Episode: 884, Total Reward: 12
# Episode: 885, Total Reward: 9
# Episode: 886, Total Reward: 3
# Episode: 887, Total Reward: -23
# Episode: 888, Total Reward: 8
# Episode: 889, Total Reward: -13
# Episode: 890, Total Reward: 3
# Episode: 891, Total Reward: 0
# Episode: 892, Total Reward: 10
# Episode: 893, Total Reward: 10
# Episode: 894, Total Reward: 3
# Episode: 895, Total Reward: -58
# Episode: 896, Total Reward: -1
# Episode: 897, Total Reward: 2
# Episode: 898, Total Reward: 7
# Episode: 899, Total Reward: -24
# Episode: 900, Total Reward: 9
# Episode: 901, Total Reward: 11
# Episode: 902, Total Reward: 4
# Episode: 903, Total Reward: 13
# Episode: 904, Total Reward: 14
# Episode: 905, Total Reward: 10
# Episode: 906, Total Reward: 10
# Episode: 907, Total Reward: -3
# Episode: 908, Total Reward: 10
# Episode: 909, Total Reward: 1
# Episode: 910, Total Reward: 7
# Episode: 911, Total Reward: 11
# Episode: 912, Total Reward: -9
# Episode: 913, Total Reward: -75
# Episode: 914, Total Reward: 10
# Episode: 915, Total Reward: -12
# Episode: 916, Total Reward: 2
# Episode: 917, Total Reward: 14
# Episode: 918, Total Reward: -7
# Episode: 919, Total Reward: -10
# Episode: 920, Total Reward: 10
# Episode: 921, Total Reward: -5
# Episode: 922, Total Reward: 6
# Episode: 923, Total Reward: 9
# Episode: 924, Total Reward: 6
# Episode: 925, Total Reward: -34
# Episode: 926, Total Reward: 10
# Episode: 927, Total Reward: -2
# Episode: 928, Total Reward: -35
# Episode: 929, Total Reward: 11
# Episode: 930, Total Reward: -61
# Episode: 931, Total Reward: 5
# Episode: 932, Total Reward: -1
# Episode: 933, Total Reward: -5
# Episode: 934, Total Reward: 14
# Episode: 935, Total Reward: -59
# Episode: 936, Total Reward: -8
# Episode: 937, Total Reward: 3
# Episode: 938, Total Reward: -29
# Episode: 939, Total Reward: 7
# Episode: 940, Total Reward: 7
# Episode: 941, Total Reward: -70
# Episode: 942, Total Reward: -10
# Episode: 943, Total Reward: 6
# Episode: 944, Total Reward: 6
# Episode: 945, Total Reward: 11
# Episode: 946, Total Reward: 3
# Episode: 947, Total Reward: 7
# Episode: 948, Total Reward: 1
# Episode: 949, Total Reward: -78
# Episode: 950, Total Reward: 9
# Episode: 951, Total Reward: 10
# Episode: 952, Total Reward: -30
# Episode: 953, Total Reward: -20
# Episode: 954, Total Reward: 11
# Episode: 955, Total Reward: 6
# Episode: 956, Total Reward: 11
# Episode: 957, Total Reward: -7
# Episode: 958, Total Reward: 3
# Episode: 959, Total Reward: -29
# Episode: 960, Total Reward: 9
# Episode: 961, Total Reward: 6
# Episode: 962, Total Reward: -8
# Episode: 963, Total Reward: 7
# Episode: 964, Total Reward: 3
# Episode: 965, Total Reward: 9
# Episode: 966, Total Reward: 9
# Episode: 967, Total Reward: 1
# Episode: 968, Total Reward: 7
# Episode: 969, Total Reward: -6
# Episode: 970, Total Reward: -58
# Episode: 971, Total Reward: 9
# Episode: 972, Total Reward: 10
# Episode: 973, Total Reward: 10
# Episode: 974, Total Reward: 7
# Episode: 975, Total Reward: 10
# Episode: 976, Total Reward: 11
# Episode: 977, Total Reward: -4
# Episode: 978, Total Reward: 12
# Episode: 979, Total Reward: 9
# Episode: 980, Total Reward: 9
# Episode: 981, Total Reward: -14
# Episode: 982, Total Reward: -22
# Episode: 983, Total Reward: -20
# Episode: 984, Total Reward: 5
# Episode: 985, Total Reward: 10
# Episode: 986, Total Reward: 8
# Episode: 987, Total Reward: -3
# Episode: 988, Total Reward: 11
# Episode: 989, Total Reward: 14
# Episode: 990, Total Reward: -28
# Episode: 991, Total Reward: 9
# Episode: 992, Total Reward: 11
# Episode: 993, Total Reward: 10
# Episode: 994, Total Reward: 9
# Episode: 995, Total Reward: -1
# Episode: 996, Total Reward: 10
# Episode: 997, Total Reward: -14
# Episode: 998, Total Reward: 9
# Episode: 999, Total Reward: 8
# Episode: 1000, Total Reward: -49
# Episode: 1001, Total Reward: -8
# Episode: 1002, Total Reward: 7
# Episode: 1003, Total Reward: 10
# Episode: 1004, Total Reward: -68
# Episode: 1005, Total Reward: 11
# Episode: 1006, Total Reward: -19
# Episode: 1007, Total Reward: 12
# Episode: 1008, Total Reward: 2
# Episode: 1009, Total Reward: 8
# Episode: 1010, Total Reward: 9
# Episode: 1011, Total Reward: -1
# Episode: 1012, Total Reward: 1
# Episode: 1013, Total Reward: 3
# Episode: 1014, Total Reward: -43
# Episode: 1015, Total Reward: -25
# Episode: 1016, Total Reward: 10
# Episode: 1017, Total Reward: 8
# Episode: 1018, Total Reward: -9
# Episode: 1019, Total Reward: 8
# Episode: 1020, Total Reward: 13
# Episode: 1021, Total Reward: 5
# Episode: 1022, Total Reward: 14
# Episode: 1023, Total Reward: 13
# Episode: 1024, Total Reward: 11
# Episode: 1025, Total Reward: 8
# Episode: 1026, Total Reward: 8
# Episode: 1027, Total Reward: -2
# Episode: 1028, Total Reward: 5
# Episode: 1029, Total Reward: 3
# Episode: 1030, Total Reward: 3
# Episode: 1031, Total Reward: 7
# Episode: 1032, Total Reward: 14
# Episode: 1033, Total Reward: 2
# Episode: 1034, Total Reward: -2
# Episode: 1035, Total Reward: -20
# Episode: 1036, Total Reward: 4
# Episode: 1037, Total Reward: 9
# Episode: 1038, Total Reward: 6
# Episode: 1039, Total Reward: -12
# Episode: 1040, Total Reward: -21
# Episode: 1041, Total Reward: 5
# Episode: 1042, Total Reward: -51
# Episode: 1043, Total Reward: 13
# Episode: 1044, Total Reward: 8
# Episode: 1045, Total Reward: -98
# Episode: 1046, Total Reward: -24
# Episode: 1047, Total Reward: -7
# Episode: 1048, Total Reward: 12
# Episode: 1049, Total Reward: -22
# Episode: 1050, Total Reward: 4
# Episode: 1051, Total Reward: -57
# Episode: 1052, Total Reward: 8
# Episode: 1053, Total Reward: 1
# Episode: 1054, Total Reward: 11
# Episode: 1055, Total Reward: 2
# Episode: 1056, Total Reward: 11
# Episode: 1057, Total Reward: -61
# Episode: 1058, Total Reward: 0
# Episode: 1059, Total Reward: 9
# Episode: 1060, Total Reward: 11
# Episode: 1061, Total Reward: 4
# Episode: 1062, Total Reward: -35
# Episode: 1063, Total Reward: 5
# Episode: 1064, Total Reward: 7
# Episode: 1065, Total Reward: 15
# Episode: 1066, Total Reward: 10
# Episode: 1067, Total Reward: 12
# Episode: 1068, Total Reward: -4
# Episode: 1069, Total Reward: -9
# Episode: 1070, Total Reward: 11
# Episode: 1071, Total Reward: -1
# Episode: 1072, Total Reward: 9
# Episode: 1073, Total Reward: -14
# Episode: 1074, Total Reward: 6
# Episode: 1075, Total Reward: -7
# Episode: 1076, Total Reward: 10
# Episode: 1077, Total Reward: 10
# Episode: 1078, Total Reward: 4
# Episode: 1079, Total Reward: 7
# Episode: 1080, Total Reward: -27
# Episode: 1081, Total Reward: -7
# Episode: 1082, Total Reward: 7
# Episode: 1083, Total Reward: 14
# Episode: 1084, Total Reward: 7
# Episode: 1085, Total Reward: -38
# Episode: 1086, Total Reward: -2
# Episode: 1087, Total Reward: 13
# Episode: 1088, Total Reward: -26
# Episode: 1089, Total Reward: 11
# Episode: 1090, Total Reward: 11
# Episode: 1091, Total Reward: 11
# Episode: 1092, Total Reward: -17
# Episode: 1093, Total Reward: 8
# Episode: 1094, Total Reward: 3
# Episode: 1095, Total Reward: 2
# Episode: 1096, Total Reward: -25
# Episode: 1097, Total Reward: 14
# Episode: 1098, Total Reward: 4
# Episode: 1099, Total Reward: -3
# Episode: 1100, Total Reward: 9
# Episode: 1101, Total Reward: 10
# Episode: 1102, Total Reward: 11
# Episode: 1103, Total Reward: 5
# Episode: 1104, Total Reward: 10
# Episode: 1105, Total Reward: 8
# Episode: 1106, Total Reward: 6
# Episode: 1107, Total Reward: 5
# Episode: 1108, Total Reward: -5
# Episode: 1109, Total Reward: 13
# Episode: 1110, Total Reward: 9
# Episode: 1111, Total Reward: 9
# Episode: 1112, Total Reward: 7
# Episode: 1113, Total Reward: -45
# Episode: 1114, Total Reward: 10
# Episode: 1115, Total Reward: -16
# Episode: 1116, Total Reward: 8
# Episode: 1117, Total Reward: 10
# Episode: 1118, Total Reward: -2
# Episode: 1119, Total Reward: 7
# Episode: 1120, Total Reward: 11
# Episode: 1121, Total Reward: 8
# Episode: 1122, Total Reward: 8
# Episode: 1123, Total Reward: 11
# Episode: 1124, Total Reward: 9
# Episode: 1125, Total Reward: 9
# Episode: 1126, Total Reward: 3
# Episode: 1127, Total Reward: 4
# Episode: 1128, Total Reward: 10
# Episode: 1129, Total Reward: 7
# Episode: 1130, Total Reward: 3
# Episode: 1131, Total Reward: 5
# Episode: 1132, Total Reward: 11
# Episode: 1133, Total Reward: 11
# Episode: 1134, Total Reward: 10
# Episode: 1135, Total Reward: -42
# Episode: 1136, Total Reward: 2
# Episode: 1137, Total Reward: 14
# Episode: 1138, Total Reward: 8
# Episode: 1139, Total Reward: 5
# Episode: 1140, Total Reward: 9
# Episode: 1141, Total Reward: -30
# Episode: 1142, Total Reward: 9
# Episode: 1143, Total Reward: -38
# Episode: 1144, Total Reward: 8
# Episode: 1145, Total Reward: 9
# Episode: 1146, Total Reward: -6
# Episode: 1147, Total Reward: -9
# Episode: 1148, Total Reward: 1
# Episode: 1149, Total Reward: 9
# Episode: 1150, Total Reward: 8
# Episode: 1151, Total Reward: -23
# Episode: 1152, Total Reward: 10
# Episode: 1153, Total Reward: 10
# Episode: 1154, Total Reward: 8
# Episode: 1155, Total Reward: 7
# Episode: 1156, Total Reward: -7
# Episode: 1157, Total Reward: 6
# Episode: 1158, Total Reward: 2
# Episode: 1159, Total Reward: 6
# Episode: 1160, Total Reward: 12
# Episode: 1161, Total Reward: 4
# Episode: 1162, Total Reward: 4
# Episode: 1163, Total Reward: 11
# Episode: 1164, Total Reward: 6
# Episode: 1165, Total Reward: 9
# Episode: 1166, Total Reward: 8
# Episode: 1167, Total Reward: 11
# Episode: 1168, Total Reward: 11
# Episode: 1169, Total Reward: -4
# Episode: 1170, Total Reward: 11
# Episode: 1171, Total Reward: 9
# Episode: 1172, Total Reward: 5
# Episode: 1173, Total Reward: 3
# Episode: 1174, Total Reward: -12
# Episode: 1175, Total Reward: 8
# Episode: 1176, Total Reward: -28
# Episode: 1177, Total Reward: 8
# Episode: 1178, Total Reward: -69
# Episode: 1179, Total Reward: -5
# Episode: 1180, Total Reward: 10
# Episode: 1181, Total Reward: 1
# Episode: 1182, Total Reward: 10
# Episode: 1183, Total Reward: 1
# Episode: 1184, Total Reward: 9
# Episode: 1185, Total Reward: 8
# Episode: 1186, Total Reward: 7
# Episode: 1187, Total Reward: 8
# Episode: 1188, Total Reward: -8
# Episode: 1189, Total Reward: -24
# Episode: 1190, Total Reward: 7
# Episode: 1191, Total Reward: 8
# Episode: 1192, Total Reward: 7
# Episode: 1193, Total Reward: 11
# Episode: 1194, Total Reward: 10
# Episode: 1195, Total Reward: 13
# Episode: 1196, Total Reward: -6
# Episode: 1197, Total Reward: 11
# Episode: 1198, Total Reward: 1
# Episode: 1199, Total Reward: 13
# Episode: 1200, Total Reward: 8
# Episode: 1201, Total Reward: 3
# Episode: 1202, Total Reward: 11
# Episode: 1203, Total Reward: 1
# Episode: 1204, Total Reward: 8
# Episode: 1205, Total Reward: -2
# Episode: 1206, Total Reward: 2
# Episode: 1207, Total Reward: 10
# Episode: 1208, Total Reward: 9
# Episode: 1209, Total Reward: 6
# Episode: 1210, Total Reward: 12
# Episode: 1211, Total Reward: -12
# Episode: 1212, Total Reward: 6
# Episode: 1213, Total Reward: 7
# Episode: 1214, Total Reward: 6
# Episode: 1215, Total Reward: 15
# Episode: 1216, Total Reward: 8
# Episode: 1217, Total Reward: 9
# Episode: 1218, Total Reward: 8
# Episode: 1219, Total Reward: 12
# Episode: 1220, Total Reward: -9
# Episode: 1221, Total Reward: 11
# Episode: 1222, Total Reward: -18
# Episode: 1223, Total Reward: 10
# Episode: 1224, Total Reward: 8
# Episode: 1225, Total Reward: 8
# Episode: 1226, Total Reward: 11
# Episode: 1227, Total Reward: 7
# Episode: 1228, Total Reward: 6
# Episode: 1229, Total Reward: 9
# Episode: 1230, Total Reward: 12
# Episode: 1231, Total Reward: 8
# Episode: 1232, Total Reward: 8
# Episode: 1233, Total Reward: 2
# Episode: 1234, Total Reward: 8
# Episode: 1235, Total Reward: -16
# Episode: 1236, Total Reward: 10
# Episode: 1237, Total Reward: -4
# Episode: 1238, Total Reward: 8
# Episode: 1239, Total Reward: 5
# Episode: 1240, Total Reward: -25
# Episode: 1241, Total Reward: 5
# Episode: 1242, Total Reward: -13
# Episode: 1243, Total Reward: 8
# Episode: 1244, Total Reward: 6
# Episode: 1245, Total Reward: 7
# Episode: 1246, Total Reward: 14
# Episode: 1247, Total Reward: 3
# Episode: 1248, Total Reward: -17
# Episode: 1249, Total Reward: 7
# Episode: 1250, Total Reward: 2
# Episode: 1251, Total Reward: 10
# Episode: 1252, Total Reward: 7
# Episode: 1253, Total Reward: -33
# Episode: 1254, Total Reward: 3
# Episode: 1255, Total Reward: 10
# Episode: 1256, Total Reward: 9
# Episode: 1257, Total Reward: 10
# Episode: 1258, Total Reward: -33
# Episode: 1259, Total Reward: 11
# Episode: 1260, Total Reward: 9
# Episode: 1261, Total Reward: 6
# Episode: 1262, Total Reward: 10
# Episode: 1263, Total Reward: 0
# Episode: 1264, Total Reward: 14
# Episode: 1265, Total Reward: 7
# Episode: 1266, Total Reward: 3
# Episode: 1267, Total Reward: -5
# Episode: 1268, Total Reward: -21
# Episode: 1269, Total Reward: 12
# Episode: 1270, Total Reward: 7
# Episode: 1271, Total Reward: 11
# Episode: 1272, Total Reward: -5
# Episode: 1273, Total Reward: 11
# Episode: 1274, Total Reward: 6
# Episode: 1275, Total Reward: 12
# Episode: 1276, Total Reward: -4
# Episode: 1277, Total Reward: 9
# Episode: 1278, Total Reward: -10
# Episode: 1279, Total Reward: -1
# Episode: 1280, Total Reward: 10
# Episode: 1281, Total Reward: 10
# Episode: 1282, Total Reward: 7
# Episode: 1283, Total Reward: 8
# Episode: 1284, Total Reward: 3
# Episode: 1285, Total Reward: -14
# Episode: 1286, Total Reward: 10
# Episode: 1287, Total Reward: 5
# Episode: 1288, Total Reward: -14
# Episode: 1289, Total Reward: 13
# Episode: 1290, Total Reward: 11
# Episode: 1291, Total Reward: 9
# Episode: 1292, Total Reward: 1
# Episode: 1293, Total Reward: 1
# Episode: 1294, Total Reward: 8
# Episode: 1295, Total Reward: 4
# Episode: 1296, Total Reward: 6
# Episode: 1297, Total Reward: 11
# Episode: 1298, Total Reward: 8
# Episode: 1299, Total Reward: -14
# Episode: 1300, Total Reward: 8
# Episode: 1301, Total Reward: 7
# Episode: 1302, Total Reward: -4
# Episode: 1303, Total Reward: 4
# Episode: 1304, Total Reward: 9
# Episode: 1305, Total Reward: 4
# Episode: 1306, Total Reward: 8
# Episode: 1307, Total Reward: -30
# Episode: 1308, Total Reward: 13
# Episode: 1309, Total Reward: 7
# Episode: 1310, Total Reward: 12
# Episode: 1311, Total Reward: -58
# Episode: 1312, Total Reward: -9
# Episode: 1313, Total Reward: 9
# Episode: 1314, Total Reward: 5
# Episode: 1315, Total Reward: 6
# Episode: 1316, Total Reward: -4
# Episode: 1317, Total Reward: 8
# Episode: 1318, Total Reward: -12
# Episode: 1319, Total Reward: -2
# Episode: 1320, Total Reward: 10
# Episode: 1321, Total Reward: 10
# Episode: 1322, Total Reward: -3
# Episode: 1323, Total Reward: 9
# Episode: 1324, Total Reward: 6
# Episode: 1325, Total Reward: 10
# Episode: 1326, Total Reward: 12
# Episode: 1327, Total Reward: 11
# Episode: 1328, Total Reward: 8
# Episode: 1329, Total Reward: -26
# Episode: 1330, Total Reward: -6
# Episode: 1331, Total Reward: 6
# Episode: 1332, Total Reward: 6
# Episode: 1333, Total Reward: 4
# Episode: 1334, Total Reward: 10
# Episode: 1335, Total Reward: 2
# Episode: 1336, Total Reward: -2
# Episode: 1337, Total Reward: 7
# Episode: 1338, Total Reward: 11
# Episode: 1339, Total Reward: 8
# Episode: 1340, Total Reward: 8
# Episode: 1341, Total Reward: 4
# Episode: 1342, Total Reward: 7
# Episode: 1343, Total Reward: 7
# Episode: 1344, Total Reward: 10
# Episode: 1345, Total Reward: -1
# Episode: 1346, Total Reward: 9
# Episode: 1347, Total Reward: 13
# Episode: 1348, Total Reward: 8
# Episode: 1349, Total Reward: -20
# Episode: 1350, Total Reward: 10
# Episode: 1351, Total Reward: 7
# Episode: 1352, Total Reward: 9
# Episode: 1353, Total Reward: 9
# Episode: 1354, Total Reward: 10
# Episode: 1355, Total Reward: 7
# Episode: 1356, Total Reward: 10
# Episode: 1357, Total Reward: 5
# Episode: 1358, Total Reward: 0
# Episode: 1359, Total Reward: 7
# Episode: 1360, Total Reward: -10
# Episode: 1361, Total Reward: 8
# Episode: 1362, Total Reward: 8
# Episode: 1363, Total Reward: 1
# Episode: 1364, Total Reward: 8
# Episode: 1365, Total Reward: 8
# Episode: 1366, Total Reward: 4
# Episode: 1367, Total Reward: -17
# Episode: 1368, Total Reward: 9
# Episode: 1369, Total Reward: 9
# Episode: 1370, Total Reward: 12
# Episode: 1371, Total Reward: 8
# Episode: 1372, Total Reward: 7
# Episode: 1373, Total Reward: 10
# Episode: 1374, Total Reward: 8
# Episode: 1375, Total Reward: 9
# Episode: 1376, Total Reward: 11
# Episode: 1377, Total Reward: -14
# Episode: 1378, Total Reward: 10
# Episode: 1379, Total Reward: 6
# Episode: 1380, Total Reward: 7
# Episode: 1381, Total Reward: 14
# Episode: 1382, Total Reward: 11
# Episode: 1383, Total Reward: 6
# Episode: 1384, Total Reward: 10
# Episode: 1385, Total Reward: 13
# Episode: 1386, Total Reward: 3
# Episode: 1387, Total Reward: 0
# Episode: 1388, Total Reward: -16
# Episode: 1389, Total Reward: 4
# Episode: 1390, Total Reward: 9
# Episode: 1391, Total Reward: 6
# Episode: 1392, Total Reward: 4
# Episode: 1393, Total Reward: 8
# Episode: 1394, Total Reward: 12
# Episode: 1395, Total Reward: -13
# Episode: 1396, Total Reward: 11
# Episode: 1397, Total Reward: 6
# Episode: 1398, Total Reward: 12
# Episode: 1399, Total Reward: 10
# Episode: 1400, Total Reward: 13
# Episode: 1401, Total Reward: -13
# Episode: 1402, Total Reward: 1
# Episode: 1403, Total Reward: 5
# Episode: 1404, Total Reward: 8
# Episode: 1405, Total Reward: 12
# Episode: 1406, Total Reward: -2
# Episode: 1407, Total Reward: 9
# Episode: 1408, Total Reward: 12
# Episode: 1409, Total Reward: 5
# Episode: 1410, Total Reward: 1
# Episode: 1411, Total Reward: 8
# Episode: 1412, Total Reward: 10
# Episode: 1413, Total Reward: -17
# Episode: 1414, Total Reward: 4
# Episode: 1415, Total Reward: 8
# Episode: 1416, Total Reward: 6
# Episode: 1417, Total Reward: 8
# Episode: 1418, Total Reward: 5
# Episode: 1419, Total Reward: 4
# Episode: 1420, Total Reward: 7
# Episode: 1421, Total Reward: 9
# Episode: 1422, Total Reward: 8
# Episode: 1423, Total Reward: 8
# Episode: 1424, Total Reward: 6
# Episode: 1425, Total Reward: 9
# Episode: 1426, Total Reward: 10
# Episode: 1427, Total Reward: 8
# Episode: 1428, Total Reward: 6
# Episode: 1429, Total Reward: 6
# Episode: 1430, Total Reward: 8
# Episode: 1431, Total Reward: 8
# Episode: 1432, Total Reward: 7
# Episode: 1433, Total Reward: 9
# Episode: 1434, Total Reward: 5
# Episode: 1435, Total Reward: 5
# Episode: 1436, Total Reward: 9
# Episode: 1437, Total Reward: 6
# Episode: 1438, Total Reward: 13
# Episode: 1439, Total Reward: 5
# Episode: 1440, Total Reward: 6
# Episode: 1441, Total Reward: 11
# Episode: 1442, Total Reward: 10
# Episode: 1443, Total Reward: 7
# Episode: 1444, Total Reward: 12
# Episode: 1445, Total Reward: -29
# Episode: 1446, Total Reward: 13
# Episode: 1447, Total Reward: 0
# Episode: 1448, Total Reward: 5
# Episode: 1449, Total Reward: 10
# Episode: 1450, Total Reward: 11
# Episode: 1451, Total Reward: 10
# Episode: 1452, Total Reward: 9
# Episode: 1453, Total Reward: 6
# Episode: 1454, Total Reward: -4
# Episode: 1455, Total Reward: 8
# Episode: 1456, Total Reward: 6
# Episode: 1457, Total Reward: 8
# Episode: 1458, Total Reward: 8
# Episode: 1459, Total Reward: 8
# Episode: 1460, Total Reward: 5
# Episode: 1461, Total Reward: 4
# Episode: 1462, Total Reward: 11
# Episode: 1463, Total Reward: 9
# Episode: 1464, Total Reward: 9
# Episode: 1465, Total Reward: 11
# Episode: 1466, Total Reward: 9
# Episode: 1467, Total Reward: 12
# Episode: 1468, Total Reward: 6
# Episode: 1469, Total Reward: 7
# Episode: 1470, Total Reward: 0
# Episode: 1471, Total Reward: 6
# Episode: 1472, Total Reward: 7
# Episode: 1473, Total Reward: 6
# Episode: 1474, Total Reward: 11
# Episode: 1475, Total Reward: 8
# Episode: 1476, Total Reward: 10
# Episode: 1477, Total Reward: -3
# Episode: 1478, Total Reward: 8
# Episode: 1479, Total Reward: 10
# Episode: 1480, Total Reward: -6
# Episode: 1481, Total Reward: 7
# Episode: 1482, Total Reward: 11
# Episode: 1483, Total Reward: 7
# Episode: 1484, Total Reward: 10
# Episode: 1485, Total Reward: -2
# Episode: 1486, Total Reward: 10
# Episode: 1487, Total Reward: 8
# Episode: 1488, Total Reward: 5
# Episode: 1489, Total Reward: 6
# Episode: 1490, Total Reward: 13
# Episode: 1491, Total Reward: 9
# Episode: 1492, Total Reward: 9
# Episode: 1493, Total Reward: 0
# Episode: 1494, Total Reward: 7
# Episode: 1495, Total Reward: 8
# Episode: 1496, Total Reward: 9
# Episode: 1497, Total Reward: -4
# Episode: 1498, Total Reward: 10
# Episode: 1499, Total Reward: 11
# Episode: 1500, Total Reward: 9
# Episode: 1501, Total Reward: 15
# Episode: 1502, Total Reward: 12
# Episode: 1503, Total Reward: 13
# Episode: 1504, Total Reward: 5
# Episode: 1505, Total Reward: 10
# Episode: 1506, Total Reward: 3
# Episode: 1507, Total Reward: 6
# Episode: 1508, Total Reward: 10
# Episode: 1509, Total Reward: 10
# Episode: 1510, Total Reward: 9
# Episode: 1511, Total Reward: 8
# Episode: 1512, Total Reward: 4
# Episode: 1513, Total Reward: 4
# ...
# Episode: 4490, Total Reward: 5
# Episode: 4491, Total Reward: 3
# Episode: 4492, Total Reward: 9
# Episode: 4493, Total Reward: 10
# Episode: 4494, Total Reward: 9
# Episode: 4495, Total Reward: 10
# Episode: 4496, Total Reward: 6
# Episode: 4497, Total Reward: 9
# Episode: 4498, Total Reward: 5
# Episode: 4499, Total Reward: 5
# Episode: 4500, Total Reward: 10
# Episode: 4501, Total Reward: 11
# Episode: 4502, Total Reward: 9
# Episode: 4503, Total Reward: 6
# Episode: 4504, Total Reward: 5
# Episode: 4505, Total Reward: 7
# Episode: 4506, Total Reward: 9
# Episode: 4507, Total Reward: 7
# Episode: 4508, Total Reward: 9
# Episode: 4509, Total Reward: 4
# Episode: 4510, Total Reward: 10
# Episode: 4511, Total Reward: 5
# Episode: 4512, Total Reward: 4
# Episode: 4513, Total Reward: 7
# Episode: 4514, Total Reward: 6
# Episode: 4515, Total Reward: -1
# Episode: 4516, Total Reward: 14
# Episode: 4517, Total Reward: 0
# Episode: 4518, Total Reward: 8
# Episode: 4519, Total Reward: 11
# Episode: 4520, Total Reward: 8
# Episode: 4521, Total Reward: 6
# Episode: 4522, Total Reward: 10
# Episode: 4523, Total Reward: 7
# Episode: 4524, Total Reward: 6
# Episode: 4525, Total Reward: 10
# Episode: 4526, Total Reward: 8
# Episode: 4527, Total Reward: 8
# Episode: 4528, Total Reward: 6
# Episode: 4529, Total Reward: 7
# Episode: 4530, Total Reward: 8
# Episode: 4531, Total Reward: 7
# Episode: 4532, Total Reward: 7
# Episode: 4533, Total Reward: 10
# Episode: 4534, Total Reward: 7
# Episode: 4535, Total Reward: 10
# Episode: 4536, Total Reward: 10
# Episode: 4537, Total Reward: 6
# Episode: 4538, Total Reward: 8
# Episode: 4539, Total Reward: 8
# Episode: 4540, Total Reward: 6
# Episode: 4541, Total Reward: 10
# Episode: 4542, Total Reward: 5
# Episode: 4543, Total Reward: 6
# Episode: 4544, Total Reward: 9
# Episode: 4545, Total Reward: 4
# Episode: 4546, Total Reward: 6
# Episode: 4547, Total Reward: 6
# Episode: 4548, Total Reward: 4
# Episode: 4549, Total Reward: 8
# Episode: 4550, Total Reward: 12
# Episode: 4551, Total Reward: 10
# Episode: 4552, Total Reward: 5
# Episode: 4553, Total Reward: 5
# Episode: 4554, Total Reward: 3
# Episode: 4555, Total Reward: 7
# Episode: 4556, Total Reward: 6
# Episode: 4557, Total Reward: 8
# Episode: 4558, Total Reward: 6
# Episode: 4559, Total Reward: 8
# Episode: 4560, Total Reward: 9
# Episode: 4561, Total Reward: 6
# Episode: 4562, Total Reward: 5
# Episode: 4563, Total Reward: 9
# Episode: 4564, Total Reward: 9
# Episode: 4565, Total Reward: 10
# Episode: 4566, Total Reward: 6
# Episode: 4567, Total Reward: 6
# Episode: 4568, Total Reward: 10
# Episode: 4569, Total Reward: 9
# Episode: 4570, Total Reward: 8
# Episode: 4571, Total Reward: 8
# Episode: 4572, Total Reward: 5
# Episode: 4573, Total Reward: 5
# Episode: 4574, Total Reward: 10
# Episode: 4575, Total Reward: 8
# Episode: 4576, Total Reward: 10
# Episode: 4577, Total Reward: 6
# Episode: 4578, Total Reward: 6
# Episode: 4579, Total Reward: 9
# Episode: 4580, Total Reward: 11
# Episode: 4581, Total Reward: 9
# Episode: 4582, Total Reward: 3
# Episode: 4583, Total Reward: 15
# Episode: 4584, Total Reward: 7
# Episode: 4585, Total Reward: 5
# Episode: 4586, Total Reward: 7
# Episode: 4587, Total Reward: 10
# Episode: 4588, Total Reward: 4
# Episode: 4589, Total Reward: 5
# Episode: 4590, Total Reward: 4
# Episode: 4591, Total Reward: 7
# Episode: 4592, Total Reward: -5
# Episode: 4593, Total Reward: 9
# Episode: 4594, Total Reward: 8
# Episode: 4595, Total Reward: -5
# Episode: 4596, Total Reward: 11
# Episode: 4597, Total Reward: 9
# Episode: 4598, Total Reward: 6
# Episode: 4599, Total Reward: 4
# Episode: 4600, Total Reward: 8
# Episode: 4601, Total Reward: 12
# Episode: 4602, Total Reward: 4
# Episode: 4603, Total Reward: 4
# Episode: 4604, Total Reward: 5
# Episode: 4605, Total Reward: 4
# Episode: 4606, Total Reward: 10
# Episode: 4607, Total Reward: 12
# Episode: 4608, Total Reward: 5
# Episode: 4609, Total Reward: 10
# Episode: 4610, Total Reward: 4
# Episode: 4611, Total Reward: 4
# Episode: 4612, Total Reward: 6
# Episode: 4613, Total Reward: 4
# Episode: 4614, Total Reward: 6
# Episode: 4615, Total Reward: 11
# Episode: 4616, Total Reward: 6
# Episode: 4617, Total Reward: 8
# Episode: 4618, Total Reward: 3
# Episode: 4619, Total Reward: 7
# Episode: 4620, Total Reward: 7
# Episode: 4621, Total Reward: 6
# Episode: 4622, Total Reward: 9
# Episode: 4623, Total Reward: 15
# Episode: 4624, Total Reward: 9
# Episode: 4625, Total Reward: 11
# Episode: 4626, Total Reward: 7
# Episode: 4627, Total Reward: 14
# Episode: 4628, Total Reward: 4
# Episode: 4629, Total Reward: 10
# Episode: 4630, Total Reward: 6
# Episode: 4631, Total Reward: 7
# Episode: 4632, Total Reward: 9
# Episode: 4633, Total Reward: 11
# Episode: 4634, Total Reward: 12
# Episode: 4635, Total Reward: 8
# Episode: 4636, Total Reward: 12
# Episode: 4637, Total Reward: 3
# Episode: 4638, Total Reward: 3
# Episode: 4639, Total Reward: 6
# Episode: 4640, Total Reward: 9
# Episode: 4641, Total Reward: -1
# Episode: 4642, Total Reward: 6
# Episode: 4643, Total Reward: 6
# Episode: 4644, Total Reward: 5
# Episode: 4645, Total Reward: 6
# Episode: 4646, Total Reward: 7
# Episode: 4647, Total Reward: 7
# Episode: 4648, Total Reward: 8
# Episode: 4649, Total Reward: 10
# Episode: 4650, Total Reward: 6
# Episode: 4651, Total Reward: 6
# Episode: 4652, Total Reward: 7
# Episode: 4653, Total Reward: 8
# Episode: 4654, Total Reward: -3
# Episode: 4655, Total Reward: 7
# Episode: 4656, Total Reward: 6
# Episode: 4657, Total Reward: 3
# Episode: 4658, Total Reward: 10
# Episode: 4659, Total Reward: 4
# Episode: 4660, Total Reward: 7
# Episode: 4661, Total Reward: 8
# Episode: 4662, Total Reward: 8
# Episode: 4663, Total Reward: 13
# Episode: 4664, Total Reward: 8
# Episode: 4665, Total Reward: 6
# Episode: 4666, Total Reward: 6
# Episode: 4667, Total Reward: 4
# Episode: 4668, Total Reward: 6
# Episode: 4669, Total Reward: 7
# Episode: 4670, Total Reward: 6
# Episode: 4671, Total Reward: 6
# Episode: 4672, Total Reward: 11
# Episode: 4673, Total Reward: 10
# Episode: 4674, Total Reward: 4
# Episode: 4675, Total Reward: 9
# Episode: 4676, Total Reward: 12
# Episode: 4677, Total Reward: 8
# Episode: 4678, Total Reward: 9
# Episode: 4679, Total Reward: 8
# Episode: 4680, Total Reward: 7
# Episode: 4681, Total Reward: 10
# Episode: 4682, Total Reward: 7
# Episode: 4683, Total Reward: 7
# Episode: 4684, Total Reward: 5
# Episode: 4685, Total Reward: 4
# Episode: 4686, Total Reward: 12
# Episode: 4687, Total Reward: 6
# Episode: 4688, Total Reward: 5
# Episode: 4689, Total Reward: 11
# Episode: 4690, Total Reward: 6
# Episode: 4691, Total Reward: 6
# Episode: 4692, Total Reward: 4
# Episode: 4693, Total Reward: 10
# Episode: 4694, Total Reward: 12
# Episode: 4695, Total Reward: 10
# Episode: 4696, Total Reward: -4
# Episode: 4697, Total Reward: 10
# Episode: 4698, Total Reward: 7
# Episode: 4699, Total Reward: 12
# Episode: 4700, Total Reward: 12
# Episode: 4701, Total Reward: 7
# Episode: 4702, Total Reward: 8
# Episode: 4703, Total Reward: 11
# Episode: 4704, Total Reward: 5
# Episode: 4705, Total Reward: 10
# Episode: 4706, Total Reward: 7
# Episode: 4707, Total Reward: 10
# Episode: 4708, Total Reward: 4
# Episode: 4709, Total Reward: 8
# Episode: 4710, Total Reward: 10
# Episode: 4711, Total Reward: 12
# Episode: 4712, Total Reward: 7
# Episode: 4713, Total Reward: 5
# Episode: 4714, Total Reward: 5
# Episode: 4715, Total Reward: 8
# Episode: 4716, Total Reward: 9
# Episode: 4717, Total Reward: 9
# Episode: 4718, Total Reward: 14
# Episode: 4719, Total Reward: 7
# Episode: 4720, Total Reward: 8
# Episode: 4721, Total Reward: 11
# Episode: 4722, Total Reward: 6
# Episode: 4723, Total Reward: 5
# Episode: 4724, Total Reward: 11
# Episode: 4725, Total Reward: 9
# Episode: 4726, Total Reward: 4
# Episode: 4727, Total Reward: 7
# Episode: 4728, Total Reward: 8
# Episode: 4729, Total Reward: 9
# Episode: 4730, Total Reward: 10
# Episode: 4731, Total Reward: 8
# Episode: 4732, Total Reward: 10
# Episode: 4733, Total Reward: 6
# Episode: 4734, Total Reward: 6
# Episode: 4735, Total Reward: 4
# Episode: 4736, Total Reward: 12
# Episode: 4737, Total Reward: 11
# Episode: 4738, Total Reward: 10
# Episode: 4739, Total Reward: 6
# Episode: 4740, Total Reward: 9
# Episode: 4741, Total Reward: 7
# Episode: 4742, Total Reward: 9
# Episode: 4743, Total Reward: 11
# Episode: 4744, Total Reward: 6
# Episode: 4745, Total Reward: 8
# Episode: 4746, Total Reward: 0
# Episode: 4747, Total Reward: 6
# Episode: 4748, Total Reward: 7
# Episode: 4749, Total Reward: -1
# Episode: 4750, Total Reward: 5
# Episode: 4751, Total Reward: 11
# Episode: 4752, Total Reward: 10
# Episode: 4753, Total Reward: 10
# Episode: 4754, Total Reward: 8
# Episode: 4755, Total Reward: 8
# Episode: 4756, Total Reward: 5
# Episode: 4757, Total Reward: 10
# Episode: 4758, Total Reward: 8
# Episode: 4759, Total Reward: 7
# Episode: 4760, Total Reward: 7
# Episode: 4761, Total Reward: 3
# Episode: 4762, Total Reward: 6
# Episode: 4763, Total Reward: 11
# Episode: 4764, Total Reward: 9
# Episode: 4765, Total Reward: 5
# Episode: 4766, Total Reward: 4
# Episode: 4767, Total Reward: 9
# Episode: 4768, Total Reward: 9
# Episode: 4769, Total Reward: 10
# Episode: 4770, Total Reward: 6
# Episode: 4771, Total Reward: 8
# Episode: 4772, Total Reward: 7
# Episode: 4773, Total Reward: 12
# Episode: 4774, Total Reward: 7
# Episode: 4775, Total Reward: 11
# Episode: 4776, Total Reward: 8
# Episode: 4777, Total Reward: 4
# Episode: 4778, Total Reward: 8
# Episode: 4779, Total Reward: 6
# Episode: 4780, Total Reward: 11
# Episode: 4781, Total Reward: 9
# Episode: 4782, Total Reward: 12
# Episode: 4783, Total Reward: 8
# Episode: 4784, Total Reward: 11
# Episode: 4785, Total Reward: 9
# Episode: 4786, Total Reward: 13
# Episode: 4787, Total Reward: 12
# Episode: 4788, Total Reward: 7
# Episode: 4789, Total Reward: 8
# Episode: 4790, Total Reward: 8
# Episode: 4791, Total Reward: 7
# Episode: 4792, Total Reward: 7
# Episode: 4793, Total Reward: 9
# Episode: 4794, Total Reward: 9
# Episode: 4795, Total Reward: 9
# Episode: 4796, Total Reward: 7
# Episode: 4797, Total Reward: 4
# Episode: 4798, Total Reward: 10
# Episode: 4799, Total Reward: 7
# Episode: 4800, Total Reward: 6
# Episode: 4801, Total Reward: 10
# Episode: 4802, Total Reward: 4
# Episode: 4803, Total Reward: 14
# Episode: 4804, Total Reward: 3
# Episode: 4805, Total Reward: 14
# Episode: 4806, Total Reward: 11
# Episode: 4807, Total Reward: 8
# Episode: 4808, Total Reward: 8
# Episode: 4809, Total Reward: 6
# Episode: 4810, Total Reward: 10
# Episode: 4811, Total Reward: 5
# Episode: 4812, Total Reward: 5
# Episode: 4813, Total Reward: 6
# Episode: 4814, Total Reward: 4
# Episode: 4815, Total Reward: 9
# Episode: 4816, Total Reward: 3
# Episode: 4817, Total Reward: 6
# Episode: 4818, Total Reward: 5
# Episode: 4819, Total Reward: 8
# Episode: 4820, Total Reward: 6
# Episode: 4821, Total Reward: 11
# Episode: 4822, Total Reward: 8
# Episode: 4823, Total Reward: 9
# Episode: 4824, Total Reward: 5
# Episode: 4825, Total Reward: 4
# Episode: 4826, Total Reward: 11
# Episode: 4827, Total Reward: 9
# Episode: 4828, Total Reward: 4
# Episode: 4829, Total Reward: 9
# Episode: 4830, Total Reward: 11
# Episode: 4831, Total Reward: 7
# Episode: 4832, Total Reward: 9
# Episode: 4833, Total Reward: 8
# Episode: 4834, Total Reward: 8
# Episode: 4835, Total Reward: 4
# Episode: 4836, Total Reward: 8
# Episode: 4837, Total Reward: 8
# Episode: 4838, Total Reward: 8
# Episode: 4839, Total Reward: 10
# Episode: 4840, Total Reward: 9
# Episode: 4841, Total Reward: 10
# Episode: 4842, Total Reward: 9
# Episode: 4843, Total Reward: 6
# Episode: 4844, Total Reward: 8
# Episode: 4845, Total Reward: 5
# Episode: 4846, Total Reward: 10
# Episode: 4847, Total Reward: 10
# Episode: 4848, Total Reward: 4
# Episode: 4849, Total Reward: 5
# Episode: 4850, Total Reward: 10
# Episode: 4851, Total Reward: 9
# Episode: 4852, Total Reward: 7
# Episode: 4853, Total Reward: 8
# Episode: 4854, Total Reward: 13
# Episode: 4855, Total Reward: 10
# Episode: 4856, Total Reward: 11
# Episode: 4857, Total Reward: 10
# Episode: 4858, Total Reward: 4
# Episode: 4859, Total Reward: 7
# Episode: 4860, Total Reward: 9
# Episode: 4861, Total Reward: 8
# Episode: 4862, Total Reward: 5
# Episode: 4863, Total Reward: 9
# Episode: 4864, Total Reward: 10
# Episode: 4865, Total Reward: 10
# Episode: 4866, Total Reward: 9
# Episode: 4867, Total Reward: 11
# Episode: 4868, Total Reward: 5
# Episode: 4869, Total Reward: 10
# Episode: 4870, Total Reward: 7
# Episode: 4871, Total Reward: 5
# Episode: 4872, Total Reward: 5
# Episode: 4873, Total Reward: 10
# Episode: 4874, Total Reward: 11
# Episode: 4875, Total Reward: 8
# Episode: 4876, Total Reward: 7
# Episode: 4877, Total Reward: 5
# Episode: 4878, Total Reward: 10
# Episode: 4879, Total Reward: 5
# Episode: 4880, Total Reward: 11
# Episode: 4881, Total Reward: 11
# Episode: 4882, Total Reward: 6
# Episode: 4883, Total Reward: 4
# Episode: 4884, Total Reward: -9
# Episode: 4885, Total Reward: 7
# Episode: 4886, Total Reward: 13
# Episode: 4887, Total Reward: -6
# Episode: 4888, Total Reward: 11
# Episode: 4889, Total Reward: 7
# Episode: 4890, Total Reward: 4
# Episode: 4891, Total Reward: 10
# Episode: 4892, Total Reward: 4
# Episode: 4893, Total Reward: 9
# Episode: 4894, Total Reward: 4
# Episode: 4895, Total Reward: 1
# Episode: 4896, Total Reward: -3
# Episode: 4897, Total Reward: 5
# Episode: 4898, Total Reward: 5
# Episode: 4899, Total Reward: 1
# Episode: 4900, Total Reward: 10
# Episode: 4901, Total Reward: 12
# Episode: 4902, Total Reward: 11
# Episode: 4903, Total Reward: 8
# Episode: 4904, Total Reward: 8
# Episode: 4905, Total Reward: -5
# Episode: 4906, Total Reward: 10
# Episode: 4907, Total Reward: 8
# Episode: 4908, Total Reward: 11
# Episode: 4909, Total Reward: 8
# Episode: 4910, Total Reward: 3
# Episode: 4911, Total Reward: 3
# Episode: 4912, Total Reward: 5
# Episode: 4913, Total Reward: 10
# Episode: 4914, Total Reward: 10
# Episode: 4915, Total Reward: 7
# Episode: 4916, Total Reward: 7
# Episode: 4917, Total Reward: 9
# Episode: 4918, Total Reward: 0
# Episode: 4919, Total Reward: 6
# Episode: 4920, Total Reward: 8
# Episode: 4921, Total Reward: 9
# Episode: 4922, Total Reward: 6
# Episode: 4923, Total Reward: 11
# Episode: 4924, Total Reward: 7
# Episode: 4925, Total Reward: 12
# Episode: 4926, Total Reward: 6
# Episode: 4927, Total Reward: 7
# Episode: 4928, Total Reward: 9
# Episode: 4929, Total Reward: 11
# Episode: 4930, Total Reward: 8
# Episode: 4931, Total Reward: 8
# Episode: 4932, Total Reward: 10
# Episode: 4933, Total Reward: 7
# Episode: 4934, Total Reward: 10
# Episode: 4935, Total Reward: 8
# Episode: 4936, Total Reward: 9
# Episode: 4937, Total Reward: 9
# Episode: 4938, Total Reward: 7
# Episode: 4939, Total Reward: 5
# Episode: 4940, Total Reward: 10
# Episode: 4941, Total Reward: 11
# Episode: 4942, Total Reward: 7
# Episode: 4943, Total Reward: 11
# Episode: 4944, Total Reward: 10
# Episode: 4945, Total Reward: 8
# Episode: 4946, Total Reward: 10
# Episode: 4947, Total Reward: 10
# Episode: 4948, Total Reward: 14
# Episode: 4949, Total Reward: 9
# Episode: 4950, Total Reward: 8
# Episode: 4951, Total Reward: 14
# Episode: 4952, Total Reward: 6
# Episode: 4953, Total Reward: 15
# Episode: 4954, Total Reward: 9
# Episode: 4955, Total Reward: 8
# Episode: 4956, Total Reward: 9
# Episode: 4957, Total Reward: 10
# Episode: 4958, Total Reward: 4
# Episode: 4959, Total Reward: 11
# Episode: 4960, Total Reward: 12
# Episode: 4961, Total Reward: 7
# Episode: 4962, Total Reward: 13
# Episode: 4963, Total Reward: 8
# Episode: 4964, Total Reward: 3
# Episode: 4965, Total Reward: 2
# Episode: 4966, Total Reward: 6
# Episode: 4967, Total Reward: 3
# Episode: 4968, Total Reward: 8
# Episode: 4969, Total Reward: 10
# Episode: 4970, Total Reward: 4
# Episode: 4971, Total Reward: 6
# Episode: 4972, Total Reward: 4
# Episode: 4973, Total Reward: 7
# Episode: 4974, Total Reward: 9
# Episode: 4975, Total Reward: 8
# Episode: 4976, Total Reward: 9
# Episode: 4977, Total Reward: 3
# Episode: 4978, Total Reward: 3
# Episode: 4979, Total Reward: 8
# Episode: 4980, Total Reward: 14
# Episode: 4981, Total Reward: 12
# Episode: 4982, Total Reward: 10
# Episode: 4983, Total Reward: -4
# Episode: 4984, Total Reward: 8
# Episode: 4985, Total Reward: 11
# Episode: 4986, Total Reward: 9
# Episode: 4987, Total Reward: 8
# Episode: 4988, Total Reward: 7
# Episode: 4989, Total Reward: 9
# Episode: 4990, Total Reward: -5
# Episode: 4991, Total Reward: 10
# Episode: 4992, Total Reward: 11
# Episode: 4993, Total Reward: 7
# Episode: 4994, Total Reward: 8
# Episode: 4995, Total Reward: 5
# Episode: 4996, Total Reward: 4
# Episode: 4997, Total Reward: 9
# Episode: 4998, Total Reward: -1
# Episode: 4999, Total Reward: 14
# Episode: 5000, Total Reward: 11

# %% [markdown]
# ## Exersice 1.2: Evaluate Q-learning
#
# Here implement greedy actions only with the learned Q-table. It is also possible to visualize the results. A coorectly implemented q-learning algorithm should get average reward of higher then 7.

# %%
# Evaluate the trained policy
env_render = gym.make("Taxi-v3", render_mode='human') # env with renderig, if you want to visualize, but it is slow. 

total_rewards = []
num_evaluation_episodes = 100

for _ in range(num_evaluation_episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        # Choose greedy action 
        
        action = np.argmax(q_table[state, :])
        new_state, reward, terminated, truncated, _ = env.step(action)
        #new_state, reward, terminated, truncated, _ = env_render.step(action) # uncomment for visualization

        done = terminated or truncated
        total_reward += reward
        state = new_state
    
    total_rewards.append(total_reward)

average_reward = np.mean(total_rewards)
print(f"Average Reward over {num_evaluation_episodes} evaluation episodes: {average_reward}")
env_render.close()
# Out:
# Average Reward over 100 evaluation episodes: 7.76

# %% [markdown]
# ## Exersice 1.3: Q-learning question
#
# Are there any limitations with Q-learning, what type of problems can it solve and what type of problems is it less suitable for?

# %% [markdown]
# # Deep Q learning
#
# In this task, we'll tackle the challenge of balancing an inverted pendulum. What makes this problem intriguing is that it involves continuous input variables, making the traditional Q-learning approach with a finite table impractical. Instead, we'll use a neural network to approximate the Q-table, enabling us to efficiently handle continuous input while still producing discrete outputs.
#
# First we will construct our neural network, this will be done in three steps. First we will define our activation function, then we will define a what a layer is and lastly we will construct the network.
#
# First let us go over the math of a neural network. They should be seen as general function approximator. A segment of neural network can be represented with a graph representation, see image below.
#
# <img src="imgs/NN_ps3.png" width="800"/>
#
#
#
# ### Naming
# * $a^i_j$ is the output of neuron j in layer i.
# * $b^i_j$ is the sum of the input to neuron j in layer i.
# * $g()$ is the activation function of a neuron (the last layer does not have a activation funciton in this case)
# * $w^i_{jk}$ is the weights of layer i going from neron k in layer i-1 to neuron j in layer i.
#
# ### Forward propagation
#
# A neural network can be seen as a function $y = f(x)$ where $x$ is an input vector and $y$ is an output vector. Forward propagation describes how we go from the input $x$ to the output $y$. Each layer can be caluculated in a sequence, where we start from the input.
#
# First each neuron $j$ in layer 1 calculated the sum of the input to that neuron:
#
# $b^1_j = \sum_{k=1}^{len(x)}( w^1_{j,k}x_k) + w^1_{j,0}$
#
# The output of the first layer is caluclated but using the activation funciton.
#
# $a^1_j = g(b^1_j)$
#
# More generally for layer $i$ and with matrix multiplication we can write this as.
#
# $b^i = w^i \begin{bmatrix} 1 \\ a^{i-1}\end{bmatrix}$
#
# where $b^i$ is a vector that has the same dimension as number of neurons in layer $i$ and the 1 added to the input is for calculating the bias.
#
# $a^i = g(b^i)$
#
# This is then caluculated sequentially until the last layer has been reashed. For the last layer without activation function we would have
#
# $\hat{y} = a^i = b^i$
#
# ### Backward propagation
#
# The way we train a network is by updating the weights $w$, they are the parameters we want to estimate to solve the problem. The way we are going to update the weights is through gradient descent. The gradients are calculated sequentially from the last layer to the first. The reason for this is that this allows us to leverage the chain rule, this saves us a lot of computational complexity.
#
# Calculating gradients:
#
# For each parameter (weight) in the neural network we will calculate a gradient:
# $\frac{\partial \mathcal{L}}{\partial w^i_{jk}}$
# where $\mathcal{L(\mathbf{y}, \hat{\mathbf{y}})}$ is the loss function, which we want to minimize. A normal loss function could for example be the mean square error $\mathcal{L} = \frac{1}{n}\sum_{i=1}^n(y-\hat{y})^2$. The gradients can be caluclated with
#
# $\frac{\partial \mathcal{L}}{\partial w^i_{jk}} = \Delta^i_{j} a^{i-1}_k$
#
# where $\Delta^i_j$ can be seen as the "precived" error for the input to neuron $j$ in layer $i$. It can be calculated with the chain rule. Let $n(i)$ be a function that returns the number of neuron of layer $i$.
#
# $\Delta^i_j = \left( \sum_{r=1}^{n(i+1)} \Delta^{i+1}_r w^{i+1}_{rj} \right) \frac{\partial g(b^i_j)}{\partial b^i_j}$
#
# For the first itteration there where is no $\Delta^{i+1}_r$ then they are calculated as:
#
# $\Delta^i_j = \frac{\partial \mathcal{L(\mathbf{y}, \hat{\mathbf{y}})}}{\partial \hat{y}_j}$
#
# This is under the assumption that there is no activation on the last layer. The nice thing is that the calculation of the vector $\Delta^i$ can be done as a matrix multiplication:
#
# $\Delta^i = (w^{i+1})^T \Delta^{i+1} \odot \nabla_{b^i} g(b^i)$
#
# where $\odot$ is elementwise multiplication and $\nabla_{b^i} g(b^i) = \begin{bmatrix} \frac{\partial g(b^i_1)}{\partial b^i_1} &...&\frac{\partial g(b^i_n)}{\partial b^i_n} \end{bmatrix}^T$.
#
# We can then calculate the gradients for a layer with:
#
# $\nabla_{w^i} \mathcal{L} = \Delta^i  (a^{i-1})^T$
#
# We are then going to update the weights with:
#
# $w^i \leftarrow w^i - \alpha(\nabla_{w^i} \mathcal{L} + \lambda w^i)$
#
# where $\alpha$ is the learning rate and $\lambda$ is a regularization term (L2 regularization), we don't want the weight to become too large. The regularization also combats overfitting to some extent. We will come back to $\nabla_{w^i}$ later.
#
# For more on the chain rule see the exersice "NN_exersice.zip" on canvas under the Exercises folder.

# %% [markdown]
# ## Exersice 2.1: ReLu
#
# Here we will implement a class for the ReLu activation function. The activation function is what allows deep neural networks to express non-linearities. The class will only have two functions, forward(x) and diff(x). The forward function takes a vector or matrix and outputs the same shape where for every element we have applied the ReLu function. The diff function returns the partial derivative of the ReLu function. This will later be used in our neural network.
#
# Hint: np.where() is useful function

# %%
class ReLu():
    def forward(self, x):
        # x is a numpy array and can have any shape. 
        # calculates the output of the ReLU function
        return np.maximum(0, x)
        
    def diff(self, x):
        # x is a numpy array and can have any shape.
        # calculates the partial differential of the ReLU function
        return np.where(x > 0, 1, 0)

# %%
relu = ReLu()

input = np.array([[1.2],[-1.1], [0.0], [10.3]])
out = relu.forward(input)
ref = np.array([[1.2],[0.0], [0.0], [10.3]])
print('forward test: ', np.array_equal(out, ref))

diff_out = relu.diff(input)
diff_ref = np.array([[1.],[0.0], [0.0], [1]])
print('diff test: ', np.array_equal(diff_out, diff_ref))
# Out:
# forward test:  True
# diff test:  True

# %% [markdown]
# ## Exersice 2.2: Layer
#
# A dense neural network is constructed by layers of neurons, here we will define a class to represent our layers. It will contain the weights and activation function for the layer. The layer class will contain two functions, forward and backward.
#
# Hint: it is a good practice to return a copy of np arrays or matrices as otherwise modifying the output can modify the internally saved matrix as it is the same object, these problems are not easy to debug. For a matrix A, then return A.copy().

# %%
class Layer(object):
    def __init__(self, num_in, num_out, activation_func=None):
        self.weights = np.random.rand(num_out, num_in+1) - 0.5  # (to layer, from layer)
        self.gradients = np.zeros((num_out, num_in+1))
        self.a_input = None  # placeholder for saving the input to the forward function
        self.b = None  # placeholder for saving the value right before the activation function
        self.activation_func = activation_func  # class instance of activation function 
        
    def forward(self, x):
        # Add a 1 for the bias term on the input, and same this in the self.a_input, this will be used in backward()
        # Calculate b, the summation in each neuron. Can be done as a matrix multiplication, save in self.b. 
        # Check if the activation function is None, otherwise run the forward of the activation function. 
        # return the output of the layer
        
        # Add bias term
        #print(x)
        bias = 1.0
        self.a_input = np.insert(x, 0, bias,axis=0).copy()
        #print("-")
        #print("a input shape", self.a_input.shape)
        #print("weights shape", self.weights.shape)
        # Calculate b using matrix multiplication
        self.b = np.dot(self.weights, self.a_input).reshape(-1, 1) # array to matrix
        #print("b shape", self.b.shape)
        #print("-----------")
        
        # Apply activation function if it's not None
        if self.activation_func is None:
            return self.b.copy()
        else:
            return self.activation_func.forward(self.b.copy()).copy()
        
    def backward(self, pre_delta, pre_w=None):
        # pre_delta is from layer i+1, pre_w is the weights from layer i+1.
        # First check it pre_w is None, it is none for the last layer (output layer).
        # Calculate this layers delta 
        # Caluclate this layers gradients and save to self.gradients (do not apply the gradients)
        # return delta from this layer 
        # Hint: see calculations above under Deep Q Learning
        
        # If pre_w is None, then it's the output layer
        if pre_w is not None:
            pre_delta = np.dot(pre_w[:, 1:].T, pre_delta)
            
        # Calculate delta for this layer
        if self.activation_func is not None:
            #print(pre_delta)
            #print(self.b)
            delta = pre_delta * self.activation_func.diff(self.b)

        else:
            delta = pre_delta.copy()

        
        # Compute the gradients
        self.gradients = np.outer(delta, self.a_input)
        
        
        return delta.copy()

# %% [markdown]
# ### Test your layer

# %%
### ------------ Test forward -------------------

layer = Layer(3, 3, ReLu())
x = np.array([[1.2], [-0.3], [4.1]])
weights = np.array([[ 0.27611978, -0.34896471, -0.33349842,  0.33546291],
          [-0.17959862, -0.36556547,  0.26716984,  0.31734925],
          [-0.11004516,  0.28841945, -0.36654527, -0.10927562]])
layer.weights = weights
ref = np.array([[1.33280959],
             [0.60270379],
             [0.        ]])
out = layer.forward(x)

if np.allclose(ref, out):
    print('OK!, Forward function matches reference')
else:
    print('Forward is not same as reference', ref, out)

### ------------ Test Backward with no activation function -------------------
layer = Layer(3, 3)
layer.weights = weights

out = layer.forward(x)

pre_delta = np.array([[0.0],[0.3],[-1.7]])
delta = layer.backward(pre_delta)

if np.allclose(pre_delta, delta):
    print('OK!, delta is correct for no activation function')
else:
    print('delta is incorrect for no activation function', delta)

    
grad_ref = np.array([[ 0.,    0.,   -0.,    0.  ],
                     [ 0.3,   0.36, -0.09,  1.23],
                     [-1.7, -2.04, 0.51,-6.97]])

if np.allclose(grad_ref, layer.gradients):
    print('OK!, gradients are correct for when no activation function')
else:
    print('gradients are incorrect for when no activation function', layer.gradients)
    
### ------------ Test Backward with activation function -------------------
    
layer = Layer(3, 3, ReLu())
layer.weights = weights

out = layer.forward(x)

pre_w  = np.array([[-0.04031945,  0.36892667, -0.47157759, -0.19271963],
                   [ 0.25223295,  0.38480469,  0.42154434,  0.13994889],
                   [ 0.07775184, -0.43675348,  0.36158881,  0.25008313]])

delta = layer.backward(pre_delta, pre_w)

ref_delta = np.array([[ 0.85792232],
                      [-0.48823767],
                      [-0.        ]])

ref_grad = np.array([[ 0.85792232,  1.02950679, -0.2573767, 3.51748152],
                     [-0.48823767, -0.58588521,  0.1464713,  -2.00177447],
                     [-0.,         -0.,          0.,         -0.       ]])

if np.allclose(ref_delta, delta):
    print('OK!, delta correct with activation function')
else:
    print('delta incorrect with activation function', delta, ref_delta)
    
if np.allclose(ref_grad, layer.gradients):
    print('OK!, gradients are correct with activation function')
else:
    print('gradients are incorrect with activation function', layer.gradients)
# Out:
# OK!, Forward function matches reference
# OK!, delta is correct for no activation function
# OK!, gradients are correct for when no activation function
# OK!, delta correct with activation function
# OK!, gradients are correct with activation function

# %% [markdown]
# ## Exercise 2.3: Define the neural network
# We will create a neural network that has two hidden layers with 64 neurons each with ReLU activation function and the output layer has the same size as the number of outputs but with no activation function.

# %%
class NeuralNetwork():
    def __init__(self, lr=1e-3, input_size=4, output_size=6, regularization=1e-4):
        # Here we create a list of the layers that we defined above
        # This is where we define the structure of our network
        self.layers = [Layer(input_size, 64, ReLu()),
                       Layer(64, 64,ReLu()),
                       Layer(64, output_size)]
        self.num_layers = len(self.layers)
        self.lr = lr
        self.regularization = regularization
        
        
    def forward(self, x):
        # Calculate the output of the neural network by itterating over the layers and return the output. 
        
        for layer in self.layers:
                x = layer.forward(x)
        return x.copy()
    

        
    
    def backward(self, loss_diff):
        # Here we caluclate the gradients.
        # The input is the partial differential of the loss function. 
        # Go backwards throught the layers and call the backwards function from the last layer and itterate 
        # towards the first layer. 
        # Hint: for i, layer in reversed(list(enumerate(self.layers))): could be useful
        # For the output layer in the network: delta = loss_diff and w_1 = None. 
        # return a python list that contains the graidients from each layer. i.e. [grad_layer_1, grad_layer_2, etc]
        gradients = [None]*self.num_layers # initialize a python list to hold the gradients 
        # Enter you solution
        w_next = None
      
        # Going backwards through the layers
        for i, layer in reversed(list(enumerate(self.layers))):
            # The last layer does not have a subsequent layer's weights and delta
            if i == self.num_layers - 1:
                delta = loss_diff
            else:
                delta = layer.backward(delta, w_next)
            
            # Compute gradients for the current layer
            gradients[i] = layer.gradients
            
            # Prepare for the next iteration
            w_next = layer.weights
            
        return gradients
    

    def update_weights(self, gradients):
        # Here we update the weights of the network, input is a list of gradients. We then want to update the weights
        # as described above with regularization. 
        # the second thing we are going to do is to clip the weights, this just ensures that we wont get any 
        # numerical problems from exploding gradients. 
        for i, grad in enumerate(gradients): 
            # UPDATE the weights here
            self.layers[i].weights -= self.lr * (grad + self.regularization * self.layers[i].weights)
            
            self.layers[i].weights = np.clip(self.layers[i].weights, -1e4, 1e4)

# %% [markdown]
# ## Test supervised learning to see if the network performes as expeced.
# Here we want to test the neural network on a simple supervised problem, it should learn the output of two functions. Does the y_est follow the true y? You should see that they follow each other fairly well, usually within 0.1 difference.

# %%
nn = NeuralNetwork(lr=1e-3, input_size=3, output_size=2)
# Train 
for i in range(10000):
    x = np.random.rand(3,1)
    y1 = 2*x[0,0] + x[0,0]*x[1,0] +1
    y2= -1*x[2,0] + 3*x[0,0]*x[2,0] 
    
    y = np.array([[y1],[y2]])
    y_est = nn.forward(x)
    #print("yest", y_est)
    
    diff_loss = -2*(y-y_est)
    loss = (y-y_est)**2
    grad = nn.backward(diff_loss)
    nn.update_weights(grad)

# Test
for i in range(5):
    x = np.random.rand(3,1)
    y1 = 2*x[0,0] + x[0,0]*x[1,0] +1
    y2= -1*x[2,0] + 3*x[0,0]*x[2,0] 
    
    y = np.array([[y1],[y2]])
    y_est = nn.forward(x)
    
    print('y:', y[:,0], 'y_est:', y_est[:,0], 'diff:', np.abs(y[:,0]-y_est[:,0]))
# Out:
# y: [ 1.23949154 -0.56832206] y_est: [ 1.32385005 -0.39716268] diff: [0.08435851 0.17115938]
# y: [2.84419597 0.62554244] y_est: [2.88696182 0.66020806] diff: [0.04276585 0.03466562]
# y: [2.52091378 0.30011785] y_est: [2.6019502 0.3254911] diff: [0.08103642 0.02537325]
# y: [ 1.06930032 -0.32298925] y_est: [ 1.05375951 -0.38666175] diff: [0.01554081 0.0636725 ]
# y: [1.94037128 0.23159865] y_est: [1.94953997 0.26989474] diff: [0.0091687  0.03829609]

# %% [markdown]
# ## Training Deep Q-learning
#
# The idea for this section is that we will walk you through the code and the process and then you will answer some theoretical questions.
#
# Now, we have a neural network, and we aim to employ it to balance an inverted pendulum on a cart. This problem involves continuous input space, with four inputs, and a discrete output space, consisting of two possible actions (left or right). The reward function for this task is straightforward - we receive a reward for every step taken, with the objective being to maintain balance. The task is considered unsuccessful if the pendulum leans too far or the cart moves excessively to the side. You can find more details about this problem at https://gymnasium.farama.org/environments/classic_control/cart_pole/.
#
# The challenge with this problem is that the continuous input space makes it impractical to use standard Q-learning, as the Q-table would become excessively large. To address this, we'll replace the Q-table with a neural network. However, as we will demonstrate, this transition is not without its challenges.
#
# The primary challenge in deep Q-learning lies in training stability, as the training process tends to be noisy, and many issues can arise. To enhance stability, we introduce three key components: target networks, experience replay, and batch gradient descent. However, before delving into those specifics, let's discuss the fundamental principle of replacing the Q-table with a neural network.
#
# In Q-learning, we maintain a table of future expected rewards, and for a given state and action, we can obtain the value, denoted as $Q(s, a)$. Our objective is to approximate this Q-value using a neural network, denoted as $f$, which takes the state as input and produces a value for each possible action, i.e., $\hat{q} = f(s)$, where $\hat{q}$ is a vector. The training loop remains similar to traditional Q-learning, but in this case, we formulate a loss function.
#
# $\mathcal{L}(s_t, a) = (q(s_t)_a -\hat{q}(s_t)_a)^2$
#
# were
#
# $q(s_t)_a = r + \gamma \underbrace{\max}_{a} \hat{q}(s_{t+1})$
#
# and $\hat{q}(s_t)_a$ is the output of the network for that action and state, and $\hat{q}(s_{t+1})$ is for the next state. This will make the network converge towarde the Q-table, atleast theoretically. The problem is that this is prone to instabilities. We can no longer initiate the network to predict zeros initially, so the initial predictions of the future reward will be completely wrong. Every time we update the weights we will also change $\underbrace{\max}_{a} \hat{q}(s_{t+1})$, that the value the network tries to converge to is allways changing, and if it varies to fast instabilities will arrise. One of the downsides of using gradient decent is that it can easily forget thing that it trained on a long time ago. The methods below attempts to minimize these issues.
#
#
# ### Target network
# The idea here is to make $\underbrace{\max}_{a} \hat{q}(s_{t+1})$ a slow varying target to increase stability. We introdue a second network called the target network. So we have two netorks $\hat{q} = f(s)$ and $\hat{q}_T = f_T(s)$, where the second is the target network. We use the second network to estimate the future estimated reward.
#
# $q(s_t, a) = r + \gamma \underbrace{\max}_{a} \hat{q}_T(s_{t+1}, a)$
#
# The idea is then to update the target network slowly towards the first network, the weights of the target network $w_T$ can then be updated with
#
# $w_T = w_T + \alpha_T (w - w_T)$
#
# where $\alpha_T$ is the target update rate. This adds stability to the traning as the future expected reward is more steady and slow changing.
#
# ### Experiance replay
#
# Next up is experience replay, because of gradient descent we don't want to train on samples that are too close to each other as there is a risk that the network will forget things it has learned. The idea is then in the training loop to not directly train on the observed data but instead save it in a buffer/queue. For training we sample for the queue, this means that the network might train on old data or new data. This minimizes that it forgets or that a lot of samples in sequence are too similar.
#
# ### Batch gradient decent
#
# To furter imporove stability we sample multiple timesteps from our memory buffer, then we caluclate the gradients for each of them and take the average of the gradients. It is then those average graidentes we use as $\nabla_{w^i}$ to update the weights, this minimize noise as each update of the weights is based on multiple data samples.
#
# We will now show how these things can be implemented in code.
#
# ## Hyper parameters
#
# Neural networks can have quite a few hyper parameters and it can be quite tricky to tune them. I have provided some hypter parameters that work, but feel free to tune them if desiered.

# %%
import random
import copy
from collections import deque # will be used to create a memory buffer

n_observation = 4 # input size, inverted pendelum (Cart Pole) 
n_actions = 2 # output size, inverted pendelum (Cart Pole)

# Hyperparameters
learn_rate = 2e-4 # learning rate, alpha
discount_factor = 0.98 # discount factor, gamma 
epsilon = 1.0 # epsilon
epsilon_max = 1.0 # epsilon max
epsilon_min = 0.05 # epsilon min
epsilon_lambda = 0.01 # epsilon decay rate
target_rate = 5e-3 # learning rate of target network
num_episodes = 500 # number of episodes the learning is 
batch_size = 128 # How many samples are used to calculate the gradients. 
regularization = 1e-4 # amount of regularization

# %% [markdown]
# ## Training function
#
# Here we define our training function, this is what will be called for every step in our trianing loop. This part is responsible for sampling a batch from the memory buffer and calculating the gradients for the batch, it is also here we have our reward function and update our network. Lastly we will update the weights of the target network.

# %%
def unpack_state(state): #this is for reshaping the state from gym to a standing vector. 
    return  np.reshape(state, (len(state),1))

# This is the training function that will be called from the traning loop
def train_network(nn, nn_target, memory):
    # nn - is the neural network, nn_target - is the target network, memory - is the memory buffer
    if len(memory) > batch_size: #check if there is enought data in the memory buffer
        grad_list = [[] for x in range(nn.num_layers)] # create a list to temporay store all the gradients
        sample = random.sample(memory, batch_size) # We sample batch_size number of samples from our memory buffer

        # we calculate the gradients for each sample that we sampled
        for i in range(batch_size): 
            state = sample[i][0]
            action = sample[i][1]
            reward = sample[i][2]
            next_state = sample[i][3]
            done = sample[i][4]
            
            # first we run a forward pass on both networks 
            pred = nn.forward(unpack_state(state))
            pred_target = nn_target.forward(unpack_state(next_state))
            
            # we create a loss vector that is zeros. We directly express it as the partial deriviative 
            diff_loss = np.zeros((n_actions,1))
            
            # we calcualte out q using the reward and the best expected reward from the target network
            q = reward + discount_factor * np.max(pred_target)*(1-done)
            # we caluclate the partial derivative loss for the action 
            diff_loss[action, 0] =  -2*(q - pred[action, 0])
        
            grad = nn.backward(diff_loss) # we calculate the gradients in the network
            
            # we append the gradients to our list for the batch 
            for k in range(nn.num_layers):
                    grad_list[k].append(grad[k])

        # After all gradients are calcultated we take the average over the batch. 
        avg_grad = []            
        for k in range(nn.num_layers):
            avg_grad.append(np.mean(grad_list[k], axis=0))
        
        # we update the weigths of the networḱ
        nn.update_weights(avg_grad)
    # Lastly we update the target network to be closer to the network, the idea is that the target updates slower
    # and therefore is less noisy. 
    for k in range(nn.num_layers):
            nn_target.layers[k].weights += target_rate*(nn.layers[k].weights - nn_target.layers[k].weights)
    return

# %% [markdown]
# ##  Training loop
#
# Here is the actual training loop that runs the simulation. This part should look similar to the q-learning training loop at the beginning of the assignment. The difference is the call of the training function and appending to the memory buffer. Because of the unstable nature of deep Q-learning, you typically save the network that performed the best during training. It can sometimes take more than 100 episodes before you see any noticeable learning.
#
# Even with all the additions of the target network, batch gradient decent and experience replay, the training can still be unstable. It is therefore common in reinforcement learning to always save the best-performing network.
#
# ## Exercise 2.4: Epsilon greedy - deep learning
# Fill code for action and update of epsilon.

# %%
# Train Deep Q-learning algorithm

# We create the environment 
env = gym.make("CartPole-v1")
#env = gym.make('LunarLander-v2')
# we create our neural network and target network, both are identical to start with. 
nn = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)
nn_target = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)
nn_target.layers = nn.layers.copy()

# A placeholder network to save the best solution. 
nn_save = NeuralNetwork(lr=learn_rate, input_size=n_observation, output_size=n_actions, regularization=regularization)

# our memory buffer, it can hold 10000 samples 
memory = deque(maxlen=10000)

# To track rewards
rewards_list = []
highest_score = 0

# train over a number of episodes
for episode in range(num_episodes):
    state, info = env.reset() # reset the environment in the beging of every episode
    done = False
    total_reward = 0

    while not done:
        # Get prediciton
        pred = nn.forward(unpack_state(state))
        
        # Calculate action with exploration-exploitation trade-off
        if np.random.rand() <= epsilon:  
            action = env.action_space.sample()  # Choose a random action
        else:
            action = np.argmax(pred)  # Choose the action with the highest predicted Q-value
        
        
        new_state, reward, terminated, truncated, _ = env.step(action) # take a step in the environment
        done = terminated or truncated # check if done
        # append to the memory buffer
        memory.append((state, action, reward, new_state, done))
        
        # call the training function
        train_network(nn, nn_target, memory)

        # update total reward and state
        total_reward += reward 
        state = new_state
        
            
    rewards_list.append(total_reward)
    # save best performing network
    if total_reward >= np.max(rewards_list):
        nn_save = copy.deepcopy(nn)
        print('save_model', total_reward)
        
    # Decay exploration probability (epsilon)
    
    epsilon = epsilon_min + (epsilon_max - epsilon_min)*np.exp(-epsilon_lambda*episode)
    print(f"Episode: {episode+1}, Total Reward: {total_reward}", 'prob ', epsilon)
# Out:
# save_model 57.0
# Episode: 1, Total Reward: 57.0 prob  1.0
# Episode: 2, Total Reward: 30.0 prob  0.9905473420617097
# Episode: 3, Total Reward: 21.0 prob  0.9811887396414175
# Episode: 4, Total Reward: 22.0 prob  0.9719232568710827
# Episode: 5, Total Reward: 30.0 prob  0.9627499671947071
# Episode: 6, Total Reward: 20.0 prob  0.9536679532756783
# Episode: 7, Total Reward: 13.0 prob  0.9446763069050362
# Episode: 8, Total Reward: 20.0 prob  0.9357741289106508
# Episode: 9, Total Reward: 16.0 prob  0.926960529067304
# Episode: 10, Total Reward: 24.0 prob  0.9182346260076668
# Episode: 11, Total Reward: 8.0 prob  0.9095955471341616
# Episode: 12, Total Reward: 17.0 prob  0.9010424285317018
# Episode: 13, Total Reward: 19.0 prob  0.8925744148812996
# Episode: 14, Total Reward: 21.0 prob  0.8841906593745332
# Episode: 15, Total Reward: 33.0 prob  0.8758903236288655
# Episode: 16, Total Reward: 25.0 prob  0.8676725776038049
# Episode: 17, Total Reward: 11.0 prob  0.8595365995179007
# Episode: 18, Total Reward: 11.0 prob  0.8514815757665646
# Episode: 19, Total Reward: 14.0 prob  0.8435067008407084
# Episode: 20, Total Reward: 15.0 prob  0.8356111772461942
# Episode: 21, Total Reward: 10.0 prob  0.8277942154240827
# Episode: 22, Total Reward: 33.0 prob  0.8200550336716778
# Episode: 23, Total Reward: 9.0 prob  0.8123928580643546
# save_model 71.0
# Episode: 24, Total Reward: 71.0 prob  0.8048069223781673
# Episode: 25, Total Reward: 8.0 prob  0.7972964680132258
# Episode: 26, Total Reward: 56.0 prob  0.7898607439178347
# Episode: 27, Total Reward: 15.0 prob  0.782499006513388
# Episode: 28, Total Reward: 42.0 prob  0.7752105196200105
# Episode: 29, Total Reward: 11.0 prob  0.7679945543829392
# Episode: 30, Total Reward: 21.0 prob  0.760850389199637
# Episode: 31, Total Reward: 21.0 prob  0.753777309647632
# Episode: 32, Total Reward: 14.0 prob  0.7467746084130747
# Episode: 33, Total Reward: 12.0 prob  0.7398415852200064
# Episode: 34, Total Reward: 19.0 prob  0.7329775467603299
# Episode: 35, Total Reward: 36.0 prob  0.7261818066244792
# Episode: 36, Total Reward: 30.0 prob  0.7194536852327778
# Episode: 37, Total Reward: 12.0 prob  0.7127925097674795
# Episode: 38, Total Reward: 12.0 prob  0.706197614105487
# Episode: 39, Total Reward: 33.0 prob  0.6996683387517381
# Episode: 40, Total Reward: 11.0 prob  0.6932040307732564
# Episode: 41, Total Reward: 15.0 prob  0.6868040437338574
# Episode: 42, Total Reward: 23.0 prob  0.6804677376295034
# Episode: 43, Total Reward: 10.0 prob  0.6741944788243039
# Episode: 44, Total Reward: 18.0 prob  0.6679836399871507
# Episode: 45, Total Reward: 11.0 prob  0.6618346000289843
# Episode: 46, Total Reward: 23.0 prob  0.6557467440406847
# Episode: 47, Total Reward: 26.0 prob  0.6497194632315797
# Episode: 48, Total Reward: 12.0 prob  0.6437521548685657
# Episode: 49, Total Reward: 12.0 prob  0.6378442222158338
# Episode: 50, Total Reward: 16.0 prob  0.6319950744751953
# Episode: 51, Total Reward: 17.0 prob  0.6262041267270018
# Episode: 52, Total Reward: 9.0 prob  0.6204707998716527
# Episode: 53, Total Reward: 13.0 prob  0.6147945205716847
# Episode: 54, Total Reward: 16.0 prob  0.6091747211944375
# Episode: 55, Total Reward: 14.0 prob  0.6036108397552902
# Episode: 56, Total Reward: 33.0 prob  0.5981023198614623
# Episode: 57, Total Reward: 8.0 prob  0.5926486106563742
# Episode: 58, Total Reward: 12.0 prob  0.5872491667645603
# Episode: 59, Total Reward: 12.0 prob  0.5819034482371319
# Episode: 60, Total Reward: 20.0 prob  0.5766109204977817
# Episode: 61, Total Reward: 15.0 prob  0.5713710542893252
# Episode: 62, Total Reward: 19.0 prob  0.5661833256207749
# Episode: 63, Total Reward: 15.0 prob  0.5610472157149408
# Episode: 64, Total Reward: 14.0 prob  0.5559622109565523
# Episode: 65, Total Reward: 14.0 prob  0.5509278028408962
# Episode: 66, Total Reward: 27.0 prob  0.5459434879229652
# Episode: 67, Total Reward: 9.0 prob  0.5410087677671143
# Episode: 68, Total Reward: 9.0 prob  0.5361231488972154
# Episode: 69, Total Reward: 19.0 prob  0.53128614274731
# Episode: 70, Total Reward: 34.0 prob  0.5264972656127527
# Episode: 71, Total Reward: 15.0 prob  0.521756038601839
# Episode: 72, Total Reward: 11.0 prob  0.5170619875879169
# Episode: 73, Total Reward: 13.0 prob  0.512414643161973
# Episode: 74, Total Reward: 17.0 prob  0.5078135405856923
# Episode: 75, Total Reward: 13.0 prob  0.5032582197449826
# Episode: 76, Total Reward: 17.0 prob  0.49874822510396394
# Episode: 77, Total Reward: 14.0 prob  0.49428310565941375
# Episode: 78, Total Reward: 9.0 prob  0.4898624148956666
# Episode: 79, Total Reward: 12.0 prob  0.48548571073996233
# Episode: 80, Total Reward: 10.0 prob  0.481152555518238
# Episode: 81, Total Reward: 11.0 prob  0.4768625159113605
# Episode: 82, Total Reward: 12.0 prob  0.472615162911794
# Episode: 83, Total Reward: 13.0 prob  0.46841007178069927
# Episode: 84, Total Reward: 18.0 prob  0.46424682200545875
# Episode: 85, Total Reward: 10.0 prob  0.46012499725762573
# Episode: 86, Total Reward: 13.0 prob  0.4560441853512903
# Episode: 87, Total Reward: 13.0 prob  0.45200397820186133
# Episode: 88, Total Reward: 11.0 prob  0.448003971785257
# Episode: 89, Total Reward: 14.0 prob  0.4440437660975023
# Episode: 90, Total Reward: 17.0 prob  0.4401229651147282
# Episode: 91, Total Reward: 15.0 prob  0.4362411767535691
# Episode: 92, Total Reward: 20.0 prob  0.4323980128319541
# Episode: 93, Total Reward: 11.0 prob  0.4285930890302884
# Episode: 94, Total Reward: 12.0 prob  0.424826024853021
# Episode: 95, Total Reward: 15.0 prob  0.421096443590595
# Episode: 96, Total Reward: 15.0 prob  0.4174039722817761
# Episode: 97, Total Reward: 10.0 prob  0.41374824167635643
# Episode: 98, Total Reward: 13.0 prob  0.41012888619822885
# Episode: 99, Total Reward: 22.0 prob  0.4065455439088296
# Episode: 100, Total Reward: 9.0 prob  0.4029978564709434
# Episode: 101, Total Reward: 10.0 prob  0.3994854691128702
# Episode: 102, Total Reward: 12.0 prob  0.39600803059294715
# Episode: 103, Total Reward: 13.0 prob  0.39256519316442434
# Episode: 104, Total Reward: 10.0 prob  0.38915661254069
# Episode: 105, Total Reward: 13.0 prob  0.38578194786084113
# Episode: 106, Total Reward: 9.0 prob  0.38244086165559754
# Episode: 107, Total Reward: 10.0 prob  0.3791330198135545
# Episode: 108, Total Reward: 14.0 prob  0.3758580915477713
# Episode: 109, Total Reward: 11.0 prob  0.37261574936269215
# Episode: 110, Total Reward: 13.0 prob  0.3694056690213966
# Episode: 111, Total Reward: 11.0 prob  0.36622752951317555
# Episode: 112, Total Reward: 17.0 prob  0.3630810130214296
# Episode: 113, Total Reward: 12.0 prob  0.35996580489188745
# Episode: 114, Total Reward: 12.0 prob  0.35688159360114025
# Episode: 115, Total Reward: 14.0 prob  0.3538280707254886
# Episode: 116, Total Reward: 10.0 prob  0.35080493091010045
# Episode: 117, Total Reward: 18.0 prob  0.347811871838475
# Episode: 118, Total Reward: 9.0 prob  0.34484859420221076
# Episode: 119, Total Reward: 15.0 prob  0.3419148016710747
# Episode: 120, Total Reward: 11.0 prob  0.33901020086336886
# Episode: 121, Total Reward: 14.0 prob  0.336134501316592
# Episode: 122, Total Reward: 11.0 prob  0.33328741545839297
# Episode: 123, Total Reward: 9.0 prob  0.3304686585778135
# Episode: 124, Total Reward: 8.0 prob  0.32767794879681644
# Episode: 125, Total Reward: 12.0 prob  0.3249150070420981
# Episode: 126, Total Reward: 9.0 prob  0.32217955701718054
# Episode: 127, Total Reward: 12.0 prob  0.31947132517478183
# Episode: 128, Total Reward: 10.0 prob  0.31679004068946076
# Episode: 129, Total Reward: 10.0 prob  0.3141354354305344
# Episode: 130, Total Reward: 10.0 prob  0.3115072439352647
# Episode: 131, Total Reward: 11.0 prob  0.3089052033823119
# Episode: 132, Total Reward: 10.0 prob  0.3063290535654524
# Episode: 133, Total Reward: 10.0 prob  0.3037785368675578
# Episode: 134, Total Reward: 13.0 prob  0.3012533982348327
# Episode: 135, Total Reward: 12.0 prob  0.29875338515130967
# Episode: 136, Total Reward: 14.0 prob  0.29627824761359695
# Episode: 137, Total Reward: 12.0 prob  0.2938277381058781
# Episode: 138, Total Reward: 13.0 prob  0.29140161157516026
# Episode: 139, Total Reward: 21.0 prob  0.2889996254067686
# Episode: 140, Total Reward: 12.0 prob  0.2866215394000847
# Episode: 141, Total Reward: 11.0 prob  0.2842671157445261
# Episode: 142, Total Reward: 12.0 prob  0.28193611899576526
# Episode: 143, Total Reward: 12.0 prob  0.27962831605218463
# Episode: 144, Total Reward: 11.0 prob  0.2773434761315668
# Episode: 145, Total Reward: 12.0 prob  0.27508137074801564
# Episode: 146, Total Reward: 13.0 prob  0.2728417736891078
# Episode: 147, Total Reward: 11.0 prob  0.27062446099327087
# Episode: 148, Total Reward: 12.0 prob  0.26842921092738764
# Episode: 149, Total Reward: 11.0 prob  0.2662558039646221
# Episode: 150, Total Reward: 11.0 prob  0.26410402276246675
# Episode: 151, Total Reward: 17.0 prob  0.2619736521410083
# Episode: 152, Total Reward: 14.0 prob  0.2598644790614093
# Episode: 153, Total Reward: 12.0 prob  0.257776292604604
# Episode: 154, Total Reward: 9.0 prob  0.2557088839502067
# Episode: 155, Total Reward: 10.0 prob  0.25366204635562906
# Episode: 156, Total Reward: 13.0 prob  0.2516355751354059
# Episode: 157, Total Reward: 11.0 prob  0.24962926764072646
# Episode: 158, Total Reward: 16.0 prob  0.24764292323916942
# Episode: 159, Total Reward: 10.0 prob  0.24567634329463928
# Episode: 160, Total Reward: 12.0 prob  0.24372933114750273
# Episode: 161, Total Reward: 13.0 prob  0.24180169209492258
# Episode: 162, Total Reward: 9.0 prob  0.23989323337138724
# Episode: 163, Total Reward: 11.0 prob  0.23800376412943391
# Episode: 164, Total Reward: 14.0 prob  0.23613309542056388
# Episode: 165, Total Reward: 14.0 prob  0.23428104017634727
# Episode: 166, Total Reward: 13.0 prob  0.23244741318971635
# Episode: 167, Total Reward: 12.0 prob  0.23063203109644448
# Episode: 168, Total Reward: 12.0 prob  0.22883471235680947
# Episode: 169, Total Reward: 12.0 prob  0.22705527723743946
# Episode: 170, Total Reward: 14.0 prob  0.22529354779333982
# Episode: 171, Total Reward: 11.0 prob  0.22354934785009795
# Episode: 172, Total Reward: 14.0 prob  0.221822502986266
# Episode: 173, Total Reward: 12.0 prob  0.22011284051591856
# Episode: 174, Total Reward: 12.0 prob  0.21842018947138392
# Episode: 175, Total Reward: 11.0 prob  0.21674438058614703
# Episode: 176, Total Reward: 12.0 prob  0.21508524627792286
# Episode: 177, Total Reward: 13.0 prob  0.213442620631898
# Episode: 178, Total Reward: 14.0 prob  0.21181633938413896
# Episode: 179, Total Reward: 10.0 prob  0.21020623990516574
# Episode: 180, Total Reward: 11.0 prob  0.20861216118368864
# Episode: 181, Total Reward: 12.0 prob  0.20703394381050721
# Episode: 182, Total Reward: 10.0 prob  0.20547142996256884
# Episode: 183, Total Reward: 12.0 prob  0.20392446338718673
# Episode: 184, Total Reward: 10.0 prob  0.2023928893864141
# Episode: 185, Total Reward: 13.0 prob  0.20087655480157462
# Episode: 186, Total Reward: 15.0 prob  0.19937530799794623
# Episode: 187, Total Reward: 14.0 prob  0.19788899884959743
# Episode: 188, Total Reward: 13.0 prob  0.19641747872437482
# Episode: 189, Total Reward: 11.0 prob  0.19496060046903968
# Episode: 190, Total Reward: 15.0 prob  0.1935182183945523
# Episode: 191, Total Reward: 11.0 prob  0.19209018826150326
# Episode: 192, Total Reward: 12.0 prob  0.19067636726568932
# Episode: 193, Total Reward: 14.0 prob  0.18927661402383267
# Episode: 194, Total Reward: 15.0 prob  0.18789078855944252
# Episode: 195, Total Reward: 11.0 prob  0.18651875228881776
# Episode: 196, Total Reward: 13.0 prob  0.18516036800718788
# Episode: 197, Total Reward: 19.0 prob  0.18381549987499274
# Episode: 198, Total Reward: 10.0 prob  0.18248401340429837
# Episode: 199, Total Reward: 13.0 prob  0.18116577544534818
# Episode: 200, Total Reward: 12.0 prob  0.17986065417324765
# Episode: 201, Total Reward: 15.0 prob  0.17856851907478205
# Episode: 202, Total Reward: 12.0 prob  0.1772892409353647
# Episode: 203, Total Reward: 15.0 prob  0.17602269182611563
# Episode: 204, Total Reward: 12.0 prob  0.17476874509106838
# Episode: 205, Total Reward: 19.0 prob  0.17352727533450463
# Episode: 206, Total Reward: 15.0 prob  0.172298158408414
# Episode: 207, Total Reward: 14.0 prob  0.1710812714000797
# Episode: 208, Total Reward: 15.0 prob  0.16987649261978682
# Episode: 209, Total Reward: 17.0 prob  0.16868370158865328
# Episode: 210, Total Reward: 15.0 prob  0.1675027790265821
# Episode: 211, Total Reward: 14.0 prob  0.16633360684033283
# Episode: 212, Total Reward: 15.0 prob  0.1651760681117126
# Episode: 213, Total Reward: 16.0 prob  0.16403004708588387
# Episode: 214, Total Reward: 15.0 prob  0.16289542915978916
# Episode: 215, Total Reward: 18.0 prob  0.16177210087069022
# Episode: 216, Total Reward: 15.0 prob  0.16065994988482213
# Episode: 217, Total Reward: 10.0 prob  0.1595588649861594
# Episode: 218, Total Reward: 15.0 prob  0.15846873606529466
# Episode: 219, Total Reward: 16.0 prob  0.15738945410842736
# Episode: 220, Total Reward: 20.0 prob  0.15632091118646244
# Episode: 221, Total Reward: 9.0 prob  0.15526300044421718
# Episode: 222, Total Reward: 16.0 prob  0.15421561608973583
# Episode: 223, Total Reward: 15.0 prob  0.15317865338371006
# Episode: 224, Total Reward: 17.0 prob  0.1521520086290052
# Episode: 225, Total Reward: 24.0 prob  0.15113557916029016
# Episode: 226, Total Reward: 14.0 prob  0.15012926333377113
# Episode: 227, Total Reward: 21.0 prob  0.14913296051702674
# Episode: 228, Total Reward: 14.0 prob  0.1481465710789452
# Episode: 229, Total Reward: 20.0 prob  0.14716999637976058
# Episode: 230, Total Reward: 21.0 prob  0.14620313876118923
# Episode: 231, Total Reward: 18.0 prob  0.1452459015366635
# Episode: 232, Total Reward: 17.0 prob  0.14429818898166336
# Episode: 233, Total Reward: 14.0 prob  0.14335990632414347
# Episode: 234, Total Reward: 16.0 prob  0.14243095973505612
# Episode: 235, Total Reward: 49.0 prob  0.14151125631896838
# Episode: 236, Total Reward: 10.0 prob  0.14060070410477213
# Episode: 237, Total Reward: 9.0 prob  0.13969921203648722
# Episode: 238, Total Reward: 22.0 prob  0.13880668996415554
# Episode: 239, Total Reward: 18.0 prob  0.13792304863482613
# Episode: 240, Total Reward: 15.0 prob  0.13704819968362958
# Episode: 241, Total Reward: 9.0 prob  0.1361820556249419
# Episode: 242, Total Reward: 10.0 prob  0.13532452984363524
# Episode: 243, Total Reward: 10.0 prob  0.13447553658641703
# Episode: 244, Total Reward: 20.0 prob  0.13363499095325393
# Episode: 245, Total Reward: 10.0 prob  0.13280280888888224
# Episode: 246, Total Reward: 21.0 prob  0.13197890717440197
# Episode: 247, Total Reward: 33.0 prob  0.13116320341895515
# Episode: 248, Total Reward: 10.0 prob  0.13035561605148646
# Episode: 249, Total Reward: 9.0 prob  0.12955606431258615
# Episode: 250, Total Reward: 11.0 prob  0.12876446824641402
# Episode: 251, Total Reward: 31.0 prob  0.12798074869270387
# Episode: 252, Total Reward: 10.0 prob  0.12720482727884708
# Episode: 253, Total Reward: 11.0 prob  0.12643662641205583
# Episode: 254, Total Reward: 24.0 prob  0.1256760692716031
# Episode: 255, Total Reward: 10.0 prob  0.1249230798011412
# Episode: 256, Total Reward: 11.0 prob  0.12417758270109547
# Episode: 257, Total Reward: 12.0 prob  0.12343950342113476
# Episode: 258, Total Reward: 9.0 prob  0.12270876815271593
# Episode: 259, Total Reward: 12.0 prob  0.12198530382170321
# Episode: 260, Total Reward: 10.0 prob  0.12126903808106063
# Episode: 261, Total Reward: 41.0 prob  0.12055989930361719
# Episode: 262, Total Reward: 9.0 prob  0.11985781657490424
# Episode: 263, Total Reward: 10.0 prob  0.1191627196860638
# Episode: 264, Total Reward: 11.0 prob  0.11847453912682779
# Episode: 265, Total Reward: 11.0 prob  0.11779320607856675
# Episode: 266, Total Reward: 10.0 prob  0.11711865240740811
# Episode: 267, Total Reward: 32.0 prob  0.11645081065742259
# Episode: 268, Total Reward: 10.0 prob  0.11578961404387869
# Episode: 269, Total Reward: 39.0 prob  0.11513499644656401
# Episode: 270, Total Reward: 9.0 prob  0.11448689240317338
# Episode: 271, Total Reward: 12.0 prob  0.11384523710276227
# Episode: 272, Total Reward: 11.0 prob  0.11320996637926602
# Episode: 273, Total Reward: 13.0 prob  0.1125810167050828
# Episode: 274, Total Reward: 11.0 prob  0.11195832518472115
# Episode: 275, Total Reward: 11.0 prob  0.11134182954851005
# Episode: 276, Total Reward: 10.0 prob  0.11073146814637219
# Episode: 277, Total Reward: 13.0 prob  0.11012717994165866
# Episode: 278, Total Reward: 13.0 prob  0.10952890450504549
# Episode: 279, Total Reward: 12.0 prob  0.10893658200849038
# Episode: 280, Total Reward: 10.0 prob  0.10835015321925012
# Episode: 281, Total Reward: 13.0 prob  0.10776955949395706
# Episode: 282, Total Reward: 11.0 prob  0.10719474277275487
# Episode: 283, Total Reward: 12.0 prob  0.1066256455734924
# Episode: 284, Total Reward: 13.0 prob  0.10606221098597546
# Episode: 285, Total Reward: 9.0 prob  0.10550438266627579
# Episode: 286, Total Reward: 11.0 prob  0.10495210483109654
# Episode: 287, Total Reward: 11.0 prob  0.10440532225219398
# Episode: 288, Total Reward: 14.0 prob  0.10386398025085455
# save_model 80.0
# Episode: 289, Total Reward: 80.0 prob  0.10332802469242704
# Episode: 290, Total Reward: 12.0 prob  0.1027974019809089
# Episode: 291, Total Reward: 15.0 prob  0.10227205905358687
# Episode: 292, Total Reward: 54.0 prob  0.10175194337573037
# Episode: 293, Total Reward: 51.0 prob  0.10123700293533822
# Episode: 294, Total Reward: 11.0 prob  0.10072718623793722
# Episode: 295, Total Reward: 14.0 prob  0.10022244230143285
# Episode: 296, Total Reward: 11.0 prob  0.09972272065101076
# Episode: 297, Total Reward: 12.0 prob  0.09922797131408954
# Episode: 298, Total Reward: 13.0 prob  0.09873814481532316
# Episode: 299, Total Reward: 14.0 prob  0.09825319217165357
# Episode: 300, Total Reward: 13.0 prob  0.09777306488741228
# Episode: 301, Total Reward: 17.0 prob  0.09729771494947075
# Episode: 302, Total Reward: 13.0 prob  0.09682709482243904
# Episode: 303, Total Reward: 11.0 prob  0.09636115744391231
# Episode: 304, Total Reward: 10.0 prob  0.09589985621976438
# Episode: 305, Total Reward: 19.0 prob  0.09544314501948845
# Episode: 306, Total Reward: 51.0 prob  0.09499097817158386
# Episode: 307, Total Reward: 15.0 prob  0.09454331045898906
# Episode: 308, Total Reward: 15.0 prob  0.09410009711455969
# Episode: 309, Total Reward: 38.0 prob  0.093661293816592
# Episode: 310, Total Reward: 16.0 prob  0.09322685668439049
# Episode: 311, Total Reward: 15.0 prob  0.0927967422738799
# Episode: 312, Total Reward: 14.0 prob  0.0923709075732608
# Episode: 313, Total Reward: 13.0 prob  0.09194930999870822
# Episode: 314, Total Reward: 11.0 prob  0.0915319073901134
# Episode: 315, Total Reward: 13.0 prob  0.09111865800686761
# Episode: 316, Total Reward: 15.0 prob  0.09070952052368818
# Episode: 317, Total Reward: 12.0 prob  0.09030445402648582
# Episode: 318, Total Reward: 14.0 prob  0.08990341800827328
# Episode: 319, Total Reward: 13.0 prob  0.0895063723651145
# Episode: 320, Total Reward: 10.0 prob  0.08911327739211436
# Episode: 321, Total Reward: 10.0 prob  0.0887240937794479
# Episode: 322, Total Reward: 14.0 prob  0.08833878260842959
# Episode: 323, Total Reward: 17.0 prob  0.0879573053476212
# Episode: 324, Total Reward: 12.0 prob  0.0875796238489788
# Episode: 325, Total Reward: 11.0 prob  0.08720570034403771
# Episode: 326, Total Reward: 11.0 prob  0.08683549744013591
# Episode: 327, Total Reward: 10.0 prob  0.08646897811667445
# Episode: 328, Total Reward: 12.0 prob  0.0861061057214156
# Episode: 329, Total Reward: 11.0 prob  0.0857468439668174
# Episode: 330, Total Reward: 11.0 prob  0.08539115692640502
# Episode: 331, Total Reward: 13.0 prob  0.085039009031178
# Episode: 332, Total Reward: 48.0 prob  0.08469036506605337
# Episode: 333, Total Reward: 14.0 prob  0.08434519016634409
# Episode: 334, Total Reward: 14.0 prob  0.08400344981427253
# Episode: 335, Total Reward: 12.0 prob  0.08366510983551871
# Episode: 336, Total Reward: 37.0 prob  0.08333013639580278
# Episode: 337, Total Reward: 14.0 prob  0.08299849599750164
# Episode: 338, Total Reward: 12.0 prob  0.08267015547629908
# Episode: 339, Total Reward: 10.0 prob  0.08234508199786938
# Episode: 340, Total Reward: 12.0 prob  0.08202324305459377
# Episode: 341, Total Reward: 10.0 prob  0.08170460646230979
# Episode: 342, Total Reward: 12.0 prob  0.08138914035709259
# Episode: 343, Total Reward: 11.0 prob  0.08107681319206883
# Episode: 344, Total Reward: 16.0 prob  0.08076759373426169
# Episode: 345, Total Reward: 11.0 prob  0.08046145106146774
# Episode: 346, Total Reward: 14.0 prob  0.08015835455916454
# Episode: 347, Total Reward: 15.0 prob  0.07985827391744932
# Episode: 348, Total Reward: 13.0 prob  0.07956117912800782
# Episode: 349, Total Reward: 15.0 prob  0.07926704048111352
# Episode: 350, Total Reward: 14.0 prob  0.07897582856265661
# Episode: 351, Total Reward: 43.0 prob  0.07868751425120257
# Episode: 352, Total Reward: 16.0 prob  0.07840206871507999
# Episode: 353, Total Reward: 18.0 prob  0.07811946340949741
# Episode: 354, Total Reward: 56.0 prob  0.07783967007368871
# Episode: 355, Total Reward: 51.0 prob  0.07756266072808721
# Episode: 356, Total Reward: 14.0 prob  0.07728840767152745
# Episode: 357, Total Reward: 43.0 prob  0.07701688347847528
# Episode: 358, Total Reward: 16.0 prob  0.07674806099628509
# save_model 88.0
# Episode: 359, Total Reward: 88.0 prob  0.07648191334248466
# Episode: 360, Total Reward: 53.0 prob  0.07621841390208682
# Episode: 361, Total Reward: 14.0 prob  0.07595753632492794
# Episode: 362, Total Reward: 15.0 prob  0.07569925452303289
# Episode: 363, Total Reward: 20.0 prob  0.07544354266800626
# Episode: 364, Total Reward: 14.0 prob  0.07519037518844947
# Episode: 365, Total Reward: 57.0 prob  0.07493972676740357
# Episode: 366, Total Reward: 16.0 prob  0.07469157233981757
# Episode: 367, Total Reward: 19.0 prob  0.07444588709004195
# Episode: 368, Total Reward: 16.0 prob  0.07420264644934696
# Episode: 369, Total Reward: 11.0 prob  0.07396182609346585
# Episode: 370, Total Reward: 12.0 prob  0.07372340194016234
# Episode: 371, Total Reward: 46.0 prob  0.07348735014682242
# Episode: 372, Total Reward: 81.0 prob  0.07325364710807003
# Episode: 373, Total Reward: 28.0 prob  0.07302226945340656
# Episode: 374, Total Reward: 75.0 prob  0.07279319404487372
# Episode: 375, Total Reward: 74.0 prob  0.07256639797473975
# Episode: 376, Total Reward: 16.0 prob  0.07234185856320866
# Episode: 377, Total Reward: 65.0 prob  0.07211955335615215
# Episode: 378, Total Reward: 70.0 prob  0.0718994601228643
# save_model 107.0
# Episode: 379, Total Reward: 107.0 prob  0.07168155685383833
# Episode: 380, Total Reward: 68.0 prob  0.07146582175856578
# Episode: 381, Total Reward: 64.0 prob  0.0712522332633573
# Episode: 382, Total Reward: 70.0 prob  0.07104077000918545
# Episode: 383, Total Reward: 92.0 prob  0.07083141084954853
# Episode: 384, Total Reward: 89.0 prob  0.07062413484835614
# Episode: 385, Total Reward: 76.0 prob  0.07041892127783543
# Episode: 386, Total Reward: 80.0 prob  0.07021574961645831
# Episode: 387, Total Reward: 91.0 prob  0.07001459954688936
# Episode: 388, Total Reward: 69.0 prob  0.06981545095395399
# Episode: 389, Total Reward: 65.0 prob  0.06961828392262694
# Episode: 390, Total Reward: 68.0 prob  0.06942307873604077
# Episode: 391, Total Reward: 52.0 prob  0.06922981587351418
# Episode: 392, Total Reward: 61.0 prob  0.06903847600859982
# Episode: 393, Total Reward: 72.0 prob  0.06884904000715178
# Episode: 394, Total Reward: 67.0 prob  0.06866148892541203
# Episode: 395, Total Reward: 77.0 prob  0.06847580400811612
# Episode: 396, Total Reward: 71.0 prob  0.06829196668661758
# Episode: 397, Total Reward: 65.0 prob  0.06810995857703106
# Episode: 398, Total Reward: 55.0 prob  0.06792976147839391
# Episode: 399, Total Reward: 53.0 prob  0.06775135737084614
# Episode: 400, Total Reward: 65.0 prob  0.06757472841382828
# Episode: 401, Total Reward: 75.0 prob  0.06739985694429747
# Episode: 402, Total Reward: 40.0 prob  0.06722672547496103
# Episode: 403, Total Reward: 51.0 prob  0.0670553166925277
# Episode: 404, Total Reward: 51.0 prob  0.06688561345597648
# Episode: 405, Total Reward: 42.0 prob  0.06671759879484222
# Episode: 406, Total Reward: 69.0 prob  0.06655125590751884
# Episode: 407, Total Reward: 46.0 prob  0.06638656815957895
# Episode: 408, Total Reward: 63.0 prob  0.06622351908211055
# Episode: 409, Total Reward: 54.0 prob  0.06606209237007002
# Episode: 410, Total Reward: 26.0 prob  0.0659022718806516
# Episode: 411, Total Reward: 62.0 prob  0.06574404163167319
# Episode: 412, Total Reward: 56.0 prob  0.06558738579997801
# Episode: 413, Total Reward: 58.0 prob  0.06543228871985238
# Episode: 414, Total Reward: 71.0 prob  0.06527873488145901
# Episode: 415, Total Reward: 19.0 prob  0.06512670892928611
# Episode: 416, Total Reward: 47.0 prob  0.06497619566061176
# Episode: 417, Total Reward: 36.0 prob  0.06482718002398369
# Episode: 418, Total Reward: 48.0 prob  0.06467964711771404
# Episode: 419, Total Reward: 37.0 prob  0.06453358218838924
# Episode: 420, Total Reward: 57.0 prob  0.06438897062939464
# Episode: 421, Total Reward: 52.0 prob  0.06424579797945382
# Episode: 422, Total Reward: 53.0 prob  0.06410404992118249
# Episode: 423, Total Reward: 48.0 prob  0.06396371227965669
# Episode: 424, Total Reward: 49.0 prob  0.06382477102099532
# Episode: 425, Total Reward: 51.0 prob  0.06368721225095673
# Episode: 426, Total Reward: 50.0 prob  0.0635510222135493
# Episode: 427, Total Reward: 49.0 prob  0.06341618728965577
# Episode: 428, Total Reward: 58.0 prob  0.06328269399567138
# Episode: 429, Total Reward: 59.0 prob  0.06315052898215553
# Episode: 430, Total Reward: 78.0 prob  0.0630196790324967
# Episode: 431, Total Reward: 82.0 prob  0.06289013106159089
# Episode: 432, Total Reward: 75.0 prob  0.06276187211453305
# Episode: 433, Total Reward: 71.0 prob  0.06263488936532158
# Episode: 434, Total Reward: 64.0 prob  0.06250917011557576
# Episode: 435, Total Reward: 49.0 prob  0.06238470179326585
# Episode: 436, Total Reward: 61.0 prob  0.06226147195145587
# Episode: 437, Total Reward: 51.0 prob  0.062139468267058975
# Episode: 438, Total Reward: 18.0 prob  0.06201867853960504
# Episode: 439, Total Reward: 63.0 prob  0.06189909069002067
# Episode: 440, Total Reward: 54.0 prob  0.06178069275942124
# Episode: 441, Total Reward: 42.0 prob  0.06166347290791502
# Episode: 442, Total Reward: 40.0 prob  0.061547419413419194
# Episode: 443, Total Reward: 45.0 prob  0.061432520670487586
# Episode: 444, Total Reward: 81.0 prob  0.061318765189150165
# Episode: 445, Total Reward: 55.0 prob  0.06120614159376399
# Episode: 446, Total Reward: 66.0 prob  0.06109463862187567
# save_model 111.0
# Episode: 447, Total Reward: 111.0 prob  0.06098424512309511
# Episode: 448, Total Reward: 68.0 prob  0.06087495005798042
# Episode: 449, Total Reward: 84.0 prob  0.06076674249693402
# Episode: 450, Total Reward: 43.0 prob  0.060659611619109634
# Episode: 451, Total Reward: 74.0 prob  0.06055354671133019
# Episode: 452, Total Reward: 100.0 prob  0.060448537167016536
# Episode: 453, Total Reward: 68.0 prob  0.06034457248512672
# Episode: 454, Total Reward: 50.0 prob  0.06024164226910593
# Episode: 455, Total Reward: 54.0 prob  0.060139736225846785
# Episode: 456, Total Reward: 44.0 prob  0.06003884416466002
# Episode: 457, Total Reward: 47.0 prob  0.059938955996255455
# Episode: 458, Total Reward: 42.0 prob  0.059840061731733014
# Episode: 459, Total Reward: 84.0 prob  0.05974215148158382
# Episode: 460, Total Reward: 88.0 prob  0.05964521545470128
# Episode: 461, Total Reward: 44.0 prob  0.059549243957401896
# Episode: 462, Total Reward: 52.0 prob  0.059454227392456004
# Episode: 463, Total Reward: 36.0 prob  0.0593601562581279
# Episode: 464, Total Reward: 60.0 prob  0.05926702114722576
# Episode: 465, Total Reward: 50.0 prob  0.05917481274616089
# Episode: 466, Total Reward: 45.0 prob  0.05908352183401633
# Episode: 467, Total Reward: 96.0 prob  0.05899313928162481
# Episode: 468, Total Reward: 50.0 prob  0.058903656050655756
# Episode: 469, Total Reward: 45.0 prob  0.05881506319271151
# Episode: 470, Total Reward: 45.0 prob  0.05872735184843243
# save_model 114.0
# Episode: 471, Total Reward: 114.0 prob  0.05864051324661103
# Episode: 472, Total Reward: 51.0 prob  0.058554538703314736
# Episode: 473, Total Reward: 57.0 prob  0.05846941962101758
# Episode: 474, Total Reward: 42.0 prob  0.05838514748774039
# Episode: 475, Total Reward: 43.0 prob  0.05830171387619963
# Episode: 476, Total Reward: 36.0 prob  0.05821911044296461
# Episode: 477, Total Reward: 48.0 prob  0.05813732892762316
# Episode: 478, Total Reward: 88.0 prob  0.0580563611519556
# Episode: 479, Total Reward: 48.0 prob  0.0579761990191169
# Episode: 480, Total Reward: 50.0 prob  0.05789683451282696
# Episode: 481, Total Reward: 46.0 prob  0.05781825969656903
# Episode: 482, Total Reward: 85.0 prob  0.057740466712795986
# Episode: 483, Total Reward: 55.0 prob  0.05766344778214463
# Episode: 484, Total Reward: 51.0 prob  0.05758719520265773
# Episode: 485, Total Reward: 112.0 prob  0.057511701349013775
# Episode: 486, Total Reward: 56.0 prob  0.05743695867176448
# Episode: 487, Total Reward: 42.0 prob  0.05736295969657986
# Episode: 488, Total Reward: 39.0 prob  0.057289697023500716
# Episode: 489, Total Reward: 56.0 prob  0.057217163326198694
# Episode: 490, Total Reward: 49.0 prob  0.05714535135124361
# Episode: 491, Total Reward: 83.0 prob  0.05707425391737812
# Episode: 492, Total Reward: 40.0 prob  0.05700386391479961
# Episode: 493, Total Reward: 46.0 prob  0.05693417430444916
# Episode: 494, Total Reward: 58.0 prob  0.05686517811730764
# Episode: 495, Total Reward: 44.0 prob  0.05679686845369885
# Episode: 496, Total Reward: 35.0 prob  0.05672923848259952
# Episode: 497, Total Reward: 51.0 prob  0.056662281440956155
# Episode: 498, Total Reward: 59.0 prob  0.05659599063300881
# Episode: 499, Total Reward: 66.0 prob  0.05653035942962144
# Episode: 500, Total Reward: 33.0 prob  0.05646538126761902

# %% [markdown]
# Best reward we got was: 114

# %% [markdown]
# ## Plot the learning curve
# Below we plot the total reward againt the episodes, you can see that the learning is noisy and quite often it completly forgets everything after 300-400 episodes.

# %%
plt.plot(rewards_list)
plt.xlabel('episode')
plt.ylabel('total reward')
plt.show()

# %% [markdown]
# ## Test the learned policy

# %%
env = gym.make("CartPole-v1", render_mode="human")
#env = gym.make("LunarLander-v2", render_mode="human")

state, info = env.reset()
done = False
total_reward = 0

while not done:
    pred = nn_save.forward(unpack_state(state))
    action = np.argmax(pred)  # greedy
    new_state, reward, terminated, truncated, _ = env.step(action)
    if terminated:
        print("Terminated")
    if truncated:
        print("Truncated")
    done = terminated or truncated
    total_reward += reward
    state = new_state
env.close()
# Out:
# Terminated

# %% [markdown]
# ## Exersice 2.5:
#
# 1. What are the similarities between Q-learning and deep Q-learning?
# * Both are based on the bellman eq to update the Q-vals of state-action pairs.
# * Both methods often use epsilon-greedy exploration-exploitation tradeoff.
# * Both methods have the same objective of learning an optimal policy that maximises reward.
# 2. What are the differences and what implications does these difference have? Are Q-learning and deep Q-learning equally good at the same tasks or are they suited for different problems?
# * In Q learning, the Q-values are stored in a Q-table. Whereas in deep Q, a nn represents the Q-values.
# * In Q-learing large stat-action spaces can become infeasible. Deep Q is more scalable due to that a NN approximates the relationship.
# * Deep Q have the drawback of being unstable without precautions, this is due to the non-linear nature of the neural networks. Solved by experience replay and target networks. Regular Q does not have this problem. This is also true for convergence where regular Q will converge to an optimal value, whereas Deep Q is not guarranteed.
# 3. Are there any difficulties with deep Q-learning?
# * Unstable training: as mentioned in the instruction, using gradient descent can lead to runaway in the search. This is mitigated with experience replay.
# * There is also an issue with using the same network for selecting and evaluating actions. This can be solved with a target network.
# * We need alot of data to train a deep Q-network. This is not needed in the same way for regular Q learning.
# 4. What conclusion can you draw from the the learning curve?
# * We can see that we have some initial learning from 0-70. Then between 80-220 not much happens. Then we can see some spikes around episode 300. And after 350 we can see real improvement in terms of reward.
# * Between 400-500 we see very large variance, but with high rewards.
# * Conclusions: We can see that the network has in deed learned and improoved its polivy.
# * Adjustments: Due to the large variability in latter part of the episodes, we should be able to do improovements. Like changing the epsilon rate and min. And looking into increasing the capacity of experience or sampling technique.

# %% [markdown]
# # CNN and pytorch
#
# ## Exersice 3.1
#
# Now that we've gained a solid understanding of how neural networks function and how they are trained, we'll shift our focus to tackling an image classification problem. In this instance, we will utilize ready-made packages and libraries to streamline the process.
#
# Debugging neural networks is not an easy task! If you're looking for a helpful resource, the University of Amsterdam's course on debugging neural networks might provide valuable insights and techniques to address common challenges. https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/guide3/Debugging_PyTorch.html
#
# The starting initial code is based on https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html
#
# We are going to use the MNIST data set, which containts images of handwritten numbers and your task is to classify the written numbers from the images.
#
# Your task is to modify the code below to increase the accuracy to atleast 98%. There will hints written throughout below. Then in task 3.2 you will describe the changes you made and try to motivate why you made them.

# %%
import torch
from torch import nn
from torch.nn import Conv2d, BatchNorm2d, Linear, Dropout, MaxPool2d
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, RandomRotation, Compose, Normalize
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR

# %%
# Download training data from open datasets.
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    #transform=ToTensor(),
    transform=Compose([RandomRotation(10), ToTensor(),Normalize((0.1307,), (0.3081,))])  # mean and and std of dataset.
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))]),
)

# visualize the data
num_images_to_plot = 9
fig, axes = plt.subplots(3, 3, figsize=(8, 8))

for i in range(num_images_to_plot):
    image, label = training_data[i]
    ax = axes[i // 3, i % 3]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"Label: {label}")
    ax.axis('off')

plt.show()

# %%
# Batch size, this is something you can tune, but the current value is decent.  
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ## Define the neural network
#
# Here there is alot of things that can be tuned, I do encurage to add convolutional layers. While it is not neccessary to achive the accuracy, the convolutional layers are very good at images. For example a convolution layer can be defnined as following
#
# self.conv1 = nn.Conv2d(1, 3, 5)
#
# where the first input is the number of in channels. For a grey image there is only one channel, for an rgb image there is 3 channels. The second input is the number of out channels, you can see it as parrallel filters. The last input is the filter size. More infromation exists at https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html. The thing to keep in mind is the dimensions out of convolution. In this case the inpout is 1x28x28 and the output 3x24x24.
#
# In the forward funciton it can be used as
#
# x =  F.relu(self.conv1(x))
#
# And lets say you have defined a linear (dense) layer
#
# self.fd1 = nn.Linear(3 * 24 * 24, 120)
#
# They can be combined in the forward function as:
#
# x =  F.relu(self.conv1(x))
#
# x = torch.flatten(x, 1) # this flattens the output to a vector
#
# x =  F.relu(self.fd1(x))
#
#
# A lot of things can be modified here, such as number of layers, the size of the layers, the type of layers.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# Define the neural network model
class NeuralNetwork_pytorch(nn.Module):
    def __init__(self):
        super().__init__()
        self.fd1 = nn.Linear(28*28, 512) # dense layers (input, output), output is the number of neurons for the layer
        self.fd2 = nn.Linear(512, 512)
        self.fd3 = nn.Linear(512, 10)

    def forward(self, x):
        x = torch.flatten(x, 1) 
        x = F.relu(self.fd1(x))
        x = F.relu(self.fd2(x))
        x = self.fd3(x)
        return x


model = NeuralNetwork_pytorch().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork_pytorch(
#   (fd1): Linear(in_features=784, out_features=512, bias=True)
#   (fd2): Linear(in_features=512, out_features=512, bias=True)
#   (fd3): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

class NN2(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output


model = NN2().to(device)
print(model)
# Out:
# Using cpu device
# NN2(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Our traning function, nothing to modify here
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % (100*int(64/batch_size)) == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
# our test function, nothing to modify here.
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
# The training loop, here you can change the optimizer, the opimizer is how you update the weights. SGD does 
# gradient decent. Adam optimizer adds some extra steps and regularization. 

epochs = 5 # try to not change the number of epochs, we want something that learns fast. 
           # One epoch trains through all the data. 
    
#model = NeuralNetwork_pytorch().to(device)
#model = ImprovedNeuralNetwork().to(device)
model = NN2().to(device)


loss_fn = nn.CrossEntropyLoss() # you can change the loss function 

# you can change the optimizer. The optimizer is how you updates the weights and there are differnet ways to do that.
# For more info see https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/tutorial4/Optimization_and_Initialization.html#Optimization
#optimizer = torch.optim.SGD(model.parameters(), lr=1e-2) # orig
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)  # Added weight decay for L2 regularization

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.329591  [   64/60000]
# loss: 0.399947  [ 6464/60000]
# loss: 0.226378  [12864/60000]
# loss: 0.191687  [19264/60000]
# loss: 0.134360  [25664/60000]
# loss: 0.250081  [32064/60000]
# loss: 0.136684  [38464/60000]
# loss: 0.143776  [44864/60000]
# loss: 0.182244  [51264/60000]
# loss: 0.077857  [57664/60000]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.048625
#
# Epoch 2
# -------------------------------
# loss: 0.058242  [   64/60000]
# loss: 0.176739  [ 6464/60000]
# loss: 0.146324  [12864/60000]
# loss: 0.106384  [19264/60000]
# loss: 0.109314  [25664/60000]
# loss: 0.157678  [32064/60000]
# loss: 0.089296  [38464/60000]
# loss: 0.149651  [44864/60000]
# loss: 0.200662  [51264/60000]
# loss: 0.193956  [57664/60000]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.036975
#
# Epoch 3
# -------------------------------
# loss: 0.066897  [   64/60000]
# loss: 0.172564  [ 6464/60000]
# loss: 0.062378  [12864/60000]
# loss: 0.050676  [19264/60000]
# loss: 0.072419  [25664/60000]
# loss: 0.079262  [32064/60000]
# loss: 0.070244  [38464/60000]
# loss: 0.111769  [44864/60000]
# loss: 0.125934  [51264/60000]
# loss: 0.100088  [57664/60000]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.029151
#
# Epoch 4
# -------------------------------
# loss: 0.030799  [   64/60000]
# loss: 0.158111  [ 6464/60000]
# loss: 0.058441  [12864/60000]
# loss: 0.038545  [19264/60000]
# loss: 0.028905  [25664/60000]
# loss: 0.055121  [32064/60000]
# loss: 0.096617  [38464/60000]
# loss: 0.079320  [44864/60000]
# loss: 0.086023  [51264/60000]
# loss: 0.060525  [57664/60000]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.032943
#
# Epoch 5
# -------------------------------
# loss: 0.103109  [   64/60000]
# loss: 0.100126  [ 6464/60000]
# loss: 0.068045  [12864/60000]
# loss: 0.140878  [19264/60000]
# loss: 0.081417  [25664/60000]
# loss: 0.032943  [32064/60000]
# loss: 0.029984  [38464/60000]
# loss: 0.037075  [44864/60000]
# loss: 0.364120  [51264/60000]
# loss: 0.056514  [57664/60000]
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.029786
#
# Done!

# %% [markdown]
# ## Exersice 3.2: modifications
#
# What modifications did you do and what improvments did you see from them. Can you reason to why they worked?

# %% [markdown]
# With the following modification we got 99.1% accuracy, with the drawback of around 3x longer learning time.
# * Normalization was added to the transform of the training and test dataset. This was added to try to get faster convergence. For the MNIST dataset, Normalize((0.1307,), (0.3081,)) means that during preprocessing, each pixel value in the images will have 0.1307 subtracted from it (mean normalization), and then the result will be divided by 0.3081 (standard deviation scaling). The values 0.1307 and 0.3081 are the global mean and standard deviation of the MNIST dataset, respectively. This normalization aims to center and scale the dataset, helping in improving the training stability and efficiency of neural networks.
# * The optimiser was changed from SGD to ADAM. This means for this case that instead of stochastich gradient descent we use ADAM which uses adaptive learning rate.
# * A random rotation between -10 to 10 degrees for the images. This is to prevent overfitting. This yielded good results.
# * The largest difference we saw was to change the type of layers. Instead of having three linear layers, we opted to use 2 convolutional layers with relu activation. and then two sets of maxpool and dropout. Then at the end two linear layers with tropout to form the output.

# %%
# Our changes to the code:
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    #transform=ToTensor(),
    transform=Compose([RandomRotation(10), ToTensor(),Normalize((0.1307,), (0.3081,))]) # mean and and std of dataset.
)

# Download test data from open datasets.
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))]),
)

class NN2(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output
        
model = NN2().to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)  # Added weight decay for L2 regularization
